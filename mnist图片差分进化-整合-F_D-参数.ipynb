# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import load_model,Model
import random
import math
import threading
import time

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
import copy
x_tmp = copy.deepcopy(x_test[0])

# %%
#产生扰动种群
x_des = []
for r in range(100):
    for i in range(28):
        for j in range(28):
            x= random.randint(0,10000)/10000
            if x <= 0.1:
                u = x_tmp[i,j] # 期望值μ
                sig = math.sqrt(0.2) # 标准差δ
                x_ = random.uniform(u - 3*sig, u + 3*sig)
                y_sig = np.exp(-(x_ - u) ** 2 /(2* sig **2))/(math.sqrt(2*math.pi)*sig)
                y_= random.randint(0,10000)/10000
                if y_ <= y_sig:
                    if x_test[0][i,j] <= 127:
                        x_tmp[i,j] += 255*0.1
                    elif x_test[0][i,j] > 127 and x_test[0][i,j] < 229:
                        y = random.randint(0,10000)/10000
                        if y <= 0.5:
                            x_tmp[i,j] += 255*0.1
                        else:
                            x_tmp[i,j] -= 255*0.1
                    elif x_test[0][i,j] >= 229:
                        x_tmp[i,j] -= 255*0.1
    x_t = x_tmp/255-x_test[0]/255
    #x_des.append(np.array (x_t.reshape(1,784)))
    x_des.append(np.array(x_t.reshape(1,784)))
    plt.imshow(x_tmp,cmap='gray')
    plt.show()
    x_tmp = copy.deepcopy(x_test[0])

# %%
x_train = x_train.reshape(60000,784)    # 将图片摊平，变成向量

# %%
x_test = x_test.reshape(10000,784)     # 对测试集进行同样的处理

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
model = load_model('mnist_model.h5')

# %%
def Func(x):
    x_F = x[:]+x_test[0]
    result=model.predict(x_F.reshape(1,784))
    return result[0][7]

# %%
def Dis(x):   # 扰动值
    res = 0
    for i in range(784):
        l = x[i]
        res += l**2
    return res

# %%
# 攻击模块
class Atk(threading.Thread):

    def __init__(self,cond,name):
        #threading.Thread.__init__(self)
        super(Atk, self).__init__()
        self.cond = cond
        self.name = name

    def run(self):
        self.cond.acquire()
        print(self.name)
        global F
        global D
        global BEST_X
        global GENERATION
        #while GENERATION < MAX_GENERATION:
        while Func(BEST_X) >= 0.4:
        #for t in range(5):
            #print(Func(BEST_X))
            DB = Dis(BEST_X)    # 存储上一代的扰动程度
            # 变异
            for i in range(N):
                r = np.random.randint(1, N, 2)
                V[i, :] = BEST_X + SIGMA * (X[r[0], :] - X[r[1], :])
                for j in range(784):
                    if V[i, j] > 1:
                        #print(V[i, j])
                        V[i, j] = 1-(V[i, j]-1)
                        #print(V[i, j])
                    elif V[i, j] <= 1:
                        if V[i, j] + x_test[0][j] > 1:
                            # V +t = 1-(V+t-1)
                            V[i, j] = 1-(V[i, j]+2*x_test[0][j]-1)
                            #print(V[i, j])
                        elif V[i, j] + x_test[0][j] < 0:
                            V[i, j] = -x_test[0][j]
            # print(V)
            # 交叉操作
            for i in range(N):
                jRand = np.floor(np.random.random() * L)
                for j in range(L):
                    # 至少有一个分量对U[i,j]作出了贡献
                    # CR调小 有利于往BEST_X的方向进化
                    if np.random.random() > CR or j == jRand:
                        U[i, j] = X[i, j]
                    else:
                        U[i, j] = V[i, j]
                    #if np.random.random() < CR or j == jRand:
                        #U[i, j] = V[i, j]
                    #else:
                        #U[i, j] = X[i, j]
            # 计算适应度值+选择操作
            for i in range(N):
                FITS[i] = Func(X[i])
                FITS_U[i] = Func(U[i])
                DIS[i] = Dis(X[i])
                DIS_U[i] = Dis(U[i])
                
                D_ = DIS_U[i] - DB
                # 变异的种子表现更好
                if FITS[i] >= FITS_U[i] and D_ < 0.1:
                    X[i, :] = U[i, :]
                    FITS[i] = FITS_U[i]
                    if FITS_U[i] < Func(BEST_X) and D_ < 0.1:
                        BEST_X = U[i, :]
            GENERATION += 1
            
            print("最优值：", Func(BEST_X),"扰动程度：",Dis(BEST_X),"代数：",GENERATION)
            
            
            if Func(BEST_X) <= F:
                print("resume")
                D += 0.5 
                self.cond.notify()  # 唤醒一个挂起的线程
                self.cond.wait()
        self.cond.release()


# 恢复模块
class Re(threading.Thread):

    def __init__(self,cond,name):
        #threading.Thread.__init__(self)
        super(Re, self).__init__()
        self.cond = cond
        self.name = name

    def run(self):
        #time.sleep(1)
        self.cond.acquire()
        self.cond.wait()
        #print(self.name)
        global F
        global D
        global BEST_X
        global GENERATION
        #while GENERATION < MAX_GENERATION:
        while Func(BEST_X) >= 0.4:
        #for t in range(5):
            #print(Func(BEST_X))
            FB = Func(BEST_X)    # 存储上一代的置信度
            # 变异
            for i in range(N):
                r = np.random.randint(1, N, 2)
                V[i, :] = BEST_X + SIGMA * (X[r[0], :] - X[r[1], :])
                for j in range(784):
                    if V[i, j] > 1:
                        #print(V[i, j])
                        V[i, j] = 1-(V[i, j]-1)
                        #print(V[i, j])
                    elif V[i, j] <= 1:
                        if V[i, j] + x_test[0][j] > 1:
                            # V +t = 1-(V+t-1)
                            V[i, j] = 1-(V[i, j]+2*x_test[0][j]-1)
                            #print(V[i, j])
                        elif V[i, j] + x_test[0][j] < 0:
                            V[i, j] = -x_test[0][j]
            # print(V)
            # 交叉操作
            for i in range(N):
                jRand = np.floor(np.random.random() * L)
                for j in range(L):
                    # 至少有一个分量对U[i,j]作出了贡献
                    # CR调小 有利于往BEST_X的方向进化
                    if np.random.random() > CR or j == jRand:
                        U[i, j] = X[i, j]
                    else:
                        U[i, j] = V[i, j]
                    #if np.random.random() < CR or j == jRand:
                        #U[i, j] = V[i, j]
                    #else:
                        #U[i, j] = X[i, j]
            # 计算适应度值+选择操作
            for i in range(N):
                FITS[i] = Func(X[i])
                FITS_U[i] = Func(U[i])
                DIS[i] = Dis(X[i])
                DIS_U[i] = Dis(U[i]) 
                F_ = FITS_U[i] - FB
                
                # 变异的种子表现更好
                #if FITS[i] >= FITS_U[i] and DIS[i] >= DIS_U[i]:
                if DIS[i] >= DIS_U[i] and F_ < 0.01:
                    X[i, :] = U[i, :]
                    FITS[i] = FITS_U[i]
                    if DIS_U[i] < Dis(BEST_X) and F_ < 0.01:
                        BEST_X = U[i, :]
            GENERATION += 1
            #print(F_)
            print("最优值：", Func(BEST_X),"扰动程度：",Dis(BEST_X),"代数：",GENERATION)
            
            
            if Dis(BEST_X) <= D:
                print("attack")
                F -= 0.1
                self.cond.notify()
                self.cond.wait()
        self.cond.release()

# %%
#MAX_GENERATION = 500  # 最大迭代次数
GENERATION = 0  # 当前代数
L = 784  # 种子的维度
N = 100  # 种群规模
SIGMA = 0.333  # 缩放因子
CR = 0.1  # 交叉概率
F = 0.8   #置信度参数
D = 3.0   #扰动参数
cond = threading.Condition()
atk = Atk(cond, "attack")
re = Re(cond, "resume")

GENERATION = 0  # 当前代数
BEST_X = 0
FITS = np.zeros(N)
FITS_U = np.zeros(N)
DIS = np.zeros(N)
DIS_U = np.zeros(N)
V = np.zeros((N, L))
U = np.zeros((N, L))
# 1、初始化
X = np.concatenate(x_des, axis=0)
# 找出随机生成的最好的种子
for i in range(N):
    FITS[i] = Func(X[i])
# 找出最好的种子 适应度值最小
BEST_X = X[np.argmin(FITS)]
re.start()
atk.start()

#re.join()
#atk.join()
if Func(BEST_X) < 0.4:
    BEST_F = BEST_X+x_test[0]
    #print(BEST_X_F)
    plt.imshow(BEST_F.reshape(28,28),cmap='gray')
    plt.show()
    #break
# Out:
# attack
# 最优值： 0.9967399 扰动程度： 0.2582676984083046 代数： 1
# 最优值： 0.9965036 扰动程度： 0.32619951830834315 代数： 2
# 最优值： 0.9964419 扰动程度： 0.34936547148561153 代数： 3
# 最优值： 0.9964122 扰动程度： 0.36238342019380076 代数： 4
# 最优值： 0.99630785 扰动程度： 0.36967843962034425 代数： 5
# 最优值： 0.9961132 扰动程度： 0.3943992332484463 代数： 6
# 最优值： 0.9960466 扰动程度： 0.40779152502630106 代数： 7
# 最优值： 0.9960343 扰动程度： 0.41798276557457087 代数： 8
# 最优值： 0.9958501 扰动程度： 0.3576761413310442 代数： 9
# 最优值： 0.9958326 扰动程度： 0.3557694513765849 代数： 10
# 最优值： 0.9956025 扰动程度： 0.43359839866603667 代数： 11
# 最优值： 0.995501 扰动程度： 0.4082324963005064 代数： 12
# 最优值： 0.99545765 扰动程度： 0.4161674856922883 代数： 13
# 最优值： 0.99537575 扰动程度： 0.430697416963006 代数： 14
# 最优值： 0.9953367 扰动程度： 0.4463161841498091 代数： 15
# 最优值： 0.9952976 扰动程度： 0.44817078298204444 代数： 16
# 最优值： 0.99471056 扰动程度： 0.49376524465355265 代数： 17
# 最优值： 0.99463516 扰动程度： 0.5047609358187808 代数： 18
# 最优值： 0.99451596 扰动程度： 0.48923817976639067 代数： 19
# 最优值： 0.9945058 扰动程度： 0.4865219903083804 代数： 20
# 最优值： 0.9943158 扰动程度： 0.51297881322323 代数： 21
# 最优值： 0.99431485 扰动程度： 0.5218020908937815 代数： 22
# 最优值： 0.9941665 扰动程度： 0.5659915441478645 代数： 23
# 最优值： 0.9941989 扰动程度： 0.5171765595171469 代数： 24
# 最优值： 0.993932 扰动程度： 0.6085036461893065 代数： 25
# 最优值： 0.99372077 扰动程度： 0.6144945918210842 代数： 26
# 最优值： 0.9936661 扰动程度： 0.6139814061639298 代数： 27
# 最优值： 0.99352527 扰动程度： 0.6110031597207148 代数： 28
# 最优值： 0.9933508 扰动程度： 0.651826748957086 代数： 29
# 最优值： 0.99306935 扰动程度： 0.7415599345960298 代数： 30
# 最优值： 0.9929818 扰动程度： 0.7636091422910759 代数： 31
# 最优值： 0.9925781 扰动程度： 0.807792296177312 代数： 32
# 最优值： 0.99257445 扰动程度： 0.814790020919924 代数： 33
# 最优值： 0.9922988 扰动程度： 0.8465851739003246 代数： 34
# 最优值： 0.9922552 扰动程度： 0.8596898643535266 代数： 35
# 最优值： 0.99200726 扰动程度： 0.8916605135811958 代数： 36
# 最优值： 0.9916775 扰动程度： 0.7685885589006239 代数： 37
# 最优值： 0.99158734 扰动程度： 0.7682599021765297 代数： 38
# 最优值： 0.9915733 扰动程度： 0.816729028044996 代数： 39
# 最优值： 0.99105644 扰动程度： 0.8516166247978995 代数： 40
# 最优值： 0.98961496 扰动程度： 0.9424321736603565 代数： 41
# 最优值： 0.98970395 扰动程度： 0.9323749444092471 代数： 42
# 最优值： 0.98942137 扰动程度： 0.9572118527652492 代数： 43
# 最优值： 0.9890953 扰动程度： 0.9490399745328547 代数： 44
# 最优值： 0.9890626 扰动程度： 0.9435470390275345 代数： 45
# 最优值： 0.9890526 扰动程度： 0.9447310961894405 代数： 46
# 最优值： 0.98885334 扰动程度： 0.9577046691992691 代数： 47
# 最优值： 0.98749894 扰动程度： 1.0254151784247518 代数： 48
# 最优值： 0.98752856 扰动程度： 1.027663330491788 代数： 49
# 最优值： 0.9872585 扰动程度： 1.0569185177053448 代数： 50
# 最优值： 0.98717284 扰动程度： 1.1352536273393485 代数： 51
# 最优值： 0.9866041 扰动程度： 1.1338744803228642 代数： 52
# 最优值： 0.9864007 扰动程度： 1.1241137094199727 代数： 53
# 最优值： 0.9862292 扰动程度： 1.1597365649820353 代数： 54
# 最优值： 0.9856771 扰动程度： 1.196649350991151 代数： 55
# 最优值： 0.98535675 扰动程度： 1.2186070386819863 代数： 56
# 最优值： 0.9852365 扰动程度： 1.2125004997754858 代数： 57
# 最优值： 0.9848298 扰动程度： 1.1436268643498126 代数： 58
# 最优值： 0.9844015 扰动程度： 1.2410915163060405 代数： 59
# 最优值： 0.98405695 扰动程度： 1.2697198128834641 代数： 60
# 最优值： 0.98272574 扰动程度： 1.3578388615855053 代数： 61
# 最优值： 0.9824225 扰动程度： 1.3762850914494198 代数： 62
# 最优值： 0.9820128 扰动程度： 1.370562720759404 代数： 63
# 最优值： 0.9813306 扰动程度： 1.4254870149572259 代数： 64
# 最优值： 0.97937083 扰动程度： 1.507063543227293 代数： 65
# 最优值： 0.9796448 扰动程度： 1.49193116752239 代数： 66
# 最优值： 0.9792731 扰动程度： 1.5149475802579664 代数： 67
# 最优值： 0.9789444 扰动程度： 1.547799767206796 代数： 68
# 最优值： 0.9780057 扰动程度： 1.6434002410972037 代数： 69
# 最优值： 0.97746736 扰动程度： 1.5856837982191967 代数： 70
# 最优值： 0.9774712 扰动程度： 1.6309792403940293 代数： 71
# 最优值： 0.9765322 扰动程度： 1.650870624527343 代数： 72
# 最优值： 0.9766094 扰动程度： 1.6813257941674835 代数： 73
# 最优值： 0.9759394 扰动程度： 1.6913255455560579 代数： 74
# 最优值： 0.9751159 扰动程度： 1.7763685764750448 代数： 75
# 最优值： 0.97384566 扰动程度： 1.7935774209799287 代数： 76
# 最优值： 0.97390026 扰动程度： 1.772171669115991 代数： 77
# 最优值： 0.9734229 扰动程度： 1.8716571650681972 代数： 78
# 最优值： 0.9723799 扰动程度： 1.8616750051296085 代数： 79
# 最优值： 0.9721033 扰动程度： 1.8197624928288119 代数： 80
# 最优值： 0.9708925 扰动程度： 1.8678052052591876 代数： 81
# 最优值： 0.97052866 扰动程度： 1.8870353029128957 代数： 82
# 最优值： 0.9697195 扰动程度： 1.892093876507321 代数： 83
# 最优值： 0.96924233 扰动程度： 1.903618396736025 代数： 84
# 最优值： 0.96878237 扰动程度： 1.949655330586711 代数： 85
# 最优值： 0.96693647 扰动程度： 2.0416559299630666 代数： 86
# 最优值： 0.9661706 扰动程度： 2.074459912005029 代数： 87
# 最优值： 0.9659999 扰动程度： 2.076215239405203 代数： 88
# 最优值： 0.9643689 扰动程度： 2.066606009514494 代数： 89
# 最优值： 0.962666 扰动程度： 2.148382927672981 代数： 90
# 最优值： 0.9611876 扰动程度： 2.2347854566110232 代数： 91
# 最优值： 0.96078366 扰动程度： 2.184115159956516 代数： 92
# 最优值： 0.9606662 扰动程度： 2.1822198166780487 代数： 93
# 最优值： 0.9588384 扰动程度： 2.2347062344797264 代数： 94
# 最优值： 0.9585517 扰动程度： 2.276296387817155 代数： 95
# 最优值： 0.9564509 扰动程度： 2.3637617554623294 代数： 96
# 最优值： 0.9568146 扰动程度： 2.3021261059406966 代数： 97
# 最优值： 0.95571494 扰动程度： 2.344673896610233 代数： 98
# 最优值： 0.9554179 扰动程度： 2.3596851763636066 代数： 99
# 最优值： 0.9548605 扰动程度： 2.3721279651100566 代数： 100
# 最优值： 0.9534634 扰动程度： 2.387220461946648 代数： 101
# 最优值： 0.9525003 扰动程度： 2.4227688069769346 代数： 102
# 最优值： 0.9521198 扰动程度： 2.521683847254496 代数： 103
# 最优值： 0.95038795 扰动程度： 2.602872306415532 代数： 104
# 最优值： 0.9462237 扰动程度： 2.702593647280599 代数： 105
# 最优值： 0.94603217 扰动程度： 2.7329490571970205 代数： 106
# 最优值： 0.9439846 扰动程度： 2.680714318845546 代数： 107
# 最优值： 0.94239515 扰动程度： 2.6709924792965567 代数： 108
# 最优值： 0.94301057 扰动程度： 2.709410651333975 代数： 109
# 最优值： 0.94094455 扰动程度： 2.768685877187145 代数： 110
# 最优值： 0.93993753 扰动程度： 2.657546733407618 代数： 111
# 最优值： 0.9390258 扰动程度： 2.695103205006105 代数： 112
# 最优值： 0.9374916 扰动程度： 2.7833129382521387 代数： 113
# 最优值： 0.9369408 扰动程度： 2.8526067698504662 代数： 114
# 最优值： 0.9355965 扰动程度： 2.9030249576922946 代数： 115
# 最优值： 0.9285236 扰动程度： 2.937701678654942 代数： 116
# 最优值： 0.9288236 扰动程度： 2.9369647751906554 代数： 117
# 最优值： 0.92695767 扰动程度： 3.0234221996042137 代数： 118
# 最优值： 0.9244072 扰动程度： 3.128634582936776 代数： 119
# 最优值： 0.9259524 扰动程度： 3.033679028750821 代数： 120
# 最优值： 0.9267558 扰动程度： 3.026818477230584 代数： 121
# 最优值： 0.9245643 扰动程度： 3.067000446383481 代数： 122
# 最优值： 0.9239193 扰动程度： 3.002375286699095 代数： 123
# 最优值： 0.922105 扰动程度： 3.0293361359293054 代数： 124
# 最优值： 0.9225068 扰动程度： 3.021133599931885 代数： 125
# 最优值： 0.919992 扰动程度： 3.032117629030545 代数： 126
# 最优值： 0.91934395 扰动程度： 3.1066693699199703 代数： 127
# 最优值： 0.9164334 扰动程度： 3.1018949020672975 代数： 128
# 最优值： 0.91607094 扰动程度： 3.1099679804622937 代数： 129
# 最优值： 0.9145374 扰动程度： 3.1260896634768804 代数： 130
# 最优值： 0.9114792 扰动程度： 3.153010657783378 代数： 131
# 最优值： 0.9120816 扰动程度： 3.138888192002711 代数： 132
# 最优值： 0.9093917 扰动程度： 3.2070521260552316 代数： 133
# 最优值： 0.9081753 扰动程度： 3.236251742116507 代数： 134
# 最优值： 0.90357465 扰动程度： 3.2708822530085304 代数： 135
# 最优值： 0.9037513 扰动程度： 3.3248112363008366 代数： 136
# 最优值： 0.8966575 扰动程度： 3.418497701843421 代数： 137
# 最优值： 0.895363 扰动程度： 3.4404188385345287 代数： 138
# 最优值： 0.89492977 扰动程度： 3.515882797522698 代数： 139
# 最优值： 0.89485204 扰动程度： 3.45973999526692 代数： 140
# 最优值： 0.8922474 扰动程度： 3.5460079396885362 代数： 141
# 最优值： 0.8893534 扰动程度： 3.6248728064905955 代数： 142
# 最优值： 0.8826873 扰动程度： 3.7243375181867697 代数： 143
# 最优值： 0.88219726 扰动程度： 3.7247005694593582 代数： 144
# 最优值： 0.87392884 扰动程度： 3.7807199700050926 代数： 145
# 最优值： 0.8731628 扰动程度： 3.823468495977119 代数： 146
# 最优值： 0.8713665 扰动程度： 3.8456881109968215 代数： 147
# 最优值： 0.86872065 扰动程度： 3.8816384715023213 代数： 148
# 最优值： 0.8647989 扰动程度： 3.861259400870664 代数： 149
# 最优值： 0.8653543 扰动程度： 3.870910192955602 代数： 150
# 最优值： 0.86455894 扰动程度： 3.9099946999677453 代数： 151
# 最优值： 0.8657003 扰动程度： 3.9624337720955483 代数： 152
# 最优值： 0.8603052 扰动程度： 4.012550037295131 代数： 153
# 最优值： 0.85600847 扰动程度： 4.022284940885018 代数： 154
# 最优值： 0.85268885 扰动程度： 3.982896871298577 代数： 155
# 最优值： 0.84725624 扰动程度： 4.029975073186433 代数： 156
# 最优值： 0.84521234 扰动程度： 4.107689405728038 代数： 157
# 最优值： 0.8431551 扰动程度： 4.182877591938203 代数： 158
# 最优值： 0.84147465 扰动程度： 4.17615328782333 代数： 159
# 最优值： 0.8407911 扰动程度： 4.257799923938425 代数： 160
# 最优值： 0.82706404 扰动程度： 4.348601614607652 代数： 161
# 最优值： 0.8260221 扰动程度： 4.36056137140994 代数： 162
# 最优值： 0.82606685 扰动程度： 4.355715914475691 代数： 163
# 最优值： 0.818544 扰动程度： 4.4270829839820145 代数： 164
# 最优值： 0.8191155 扰动程度： 4.390687922338431 代数： 165
# 最优值： 0.8167251 扰动程度： 4.4440366564835765 代数： 166
# 最优值： 0.81641257 扰动程度： 4.504623073748289 代数： 167
# 最优值： 0.80957615 扰动程度： 4.515053327434228 代数： 168
# 最优值： 0.80763054 扰动程度： 4.547934412001938 代数： 169
# 最优值： 0.80712634 扰动程度： 4.482060737622201 代数： 170
# 最优值： 0.8085683 扰动程度： 4.488529151671207 代数： 171
# 最优值： 0.7997549 扰动程度： 4.58369941775293 代数： 172
# resume
# 最优值： 0.8087332 扰动程度： 4.429745014895724 代数： 173
# 最优值： 0.8135508 扰动程度： 4.3744145895542585 代数： 174
# 最优值： 0.82327425 扰动程度： 4.259666139894632 代数： 175
# 最优值： 0.8287743 扰动程度： 4.216867323591669 代数： 176
# 最优值： 0.83222175 扰动程度： 4.102900802266794 代数： 177
# 最优值： 0.8275183 扰动程度： 4.138823658442588 代数： 178
# 最优值： 0.8343763 扰动程度： 4.05771211634941 代数： 179
# 最优值： 0.8382498 扰动程度： 4.008264014631382 代数： 180
# 最优值： 0.84020716 扰动程度： 3.9981620808261806 代数： 181
# 最优值： 0.8461038 扰动程度： 3.9298871115602907 代数： 182
# 最优值： 0.8468422 扰动程度： 3.9128972506029855 代数： 183
# 最优值： 0.84826696 扰动程度： 3.8662202028704225 代数： 184
# 最优值： 0.8488078 扰动程度： 3.788547494026589 代数： 185
# 最优值： 0.84783125 扰动程度： 3.7990958671040813 代数： 186
# 最优值： 0.8575886 扰动程度： 3.774884397490773 代数： 187
# 最优值： 0.86270607 扰动程度： 3.7277059374636443 代数： 188
# 最优值： 0.86760366 扰动程度： 3.6084513009973267 代数： 189
# 最优值： 0.86625296 扰动程度： 3.6098287644968634 代数： 190
# 最优值： 0.87609047 扰动程度： 3.5522172148915954 代数： 191
# 最优值： 0.8760286 扰动程度： 3.5504792332051807 代数： 192
# 最优值： 0.8818501 扰动程度： 3.4688076296792345 代数： 193
# attack
# 最优值： 0.87502086 扰动程度： 3.536916762366327 代数： 194
# 最优值： 0.87187624 扰动程度： 3.6122245599366782 代数： 195
# 最优值： 0.85705656 扰动程度： 3.706862584170327 代数： 196
# 最优值： 0.8551248 扰动程度： 3.8061321154197807 代数： 197
# 最优值： 0.84632695 扰动程度： 3.8844911309121857 代数： 198
# 最优值： 0.84231514 扰动程度： 3.9671550500410464 代数： 199
# 最优值： 0.83597934 扰动程度： 4.052410016557194 代数： 200
# 最优值： 0.8324411 扰动程度： 4.0953617860919 代数： 201
# 最优值： 0.8334652 扰动程度： 3.967380480336582 代数： 202
# 最优值： 0.83170706 扰动程度： 3.9615879678665524 代数： 203
# 最优值： 0.8290047 扰动程度： 3.9917115815199304 代数： 204
# 最优值： 0.8278677 扰动程度： 3.995550120055705 代数： 205
# 最优值： 0.8268188 扰动程度： 4.062584455482651 代数： 206
# 最优值： 0.82075256 扰动程度： 4.157554150771226 代数： 207
# 最优值： 0.8205385 扰动程度： 4.173846472925292 代数： 208
# 最优值： 0.8149968 扰动程度： 4.156406055066851 代数： 209
# 最优值： 0.8119084 扰动程度： 4.166918005308584 代数： 210
# 最优值： 0.8061197 扰动程度： 4.214516853463513 代数： 211
# 最优值： 0.80429447 扰动程度： 4.256661468167745 代数： 212
# 最优值： 0.7995586 扰动程度： 4.274405831680754 代数： 213
# 最优值： 0.79911226 扰动程度： 4.269395794699389 代数： 214
# 最优值： 0.7960556 扰动程度： 4.35967619165369 代数： 215
# 最优值： 0.79161346 扰动程度： 4.415252509698984 代数： 216
# 最优值： 0.79073656 扰动程度： 4.481510959956168 代数： 217
# 最优值： 0.7809203 扰动程度： 4.527467329320374 代数： 218
# 最优值： 0.7792628 扰动程度： 4.571985887211781 代数： 219
# 最优值： 0.7774206 扰动程度： 4.593900125802867 代数： 220
# 最优值： 0.7746806 扰动程度： 4.615366047628751 代数： 221
# 最优值： 0.7716128 扰动程度： 4.638231187599081 代数： 222
# 最优值： 0.76655453 扰动程度： 4.666434601722934 代数： 223
# 最优值： 0.7650257 扰动程度： 4.666777972792446 代数： 224
# 最优值： 0.7615156 扰动程度： 4.684750005712744 代数： 225
# 最优值： 0.7561064 扰动程度： 4.778753462759615 代数： 226
# 最优值： 0.7546205 扰动程度： 4.77540369714535 代数： 227
# 最优值： 0.74693173 扰动程度： 4.82632956203423 代数： 228
# 最优值： 0.74135196 扰动程度： 4.885515202131142 代数： 229
# 最优值： 0.7407596 扰动程度： 4.897914681127156 代数： 230
# 最优值： 0.7315363 扰动程度： 4.989294250023724 代数： 231
# 最优值： 0.7194705 扰动程度： 5.037739879229262 代数： 232
# 最优值： 0.7183046 扰动程度： 5.052849567211989 代数： 233
# 最优值： 0.7149776 扰动程度： 5.0211101051013705 代数： 234
# 最优值： 0.7113471 扰动程度： 5.021361060157993 代数： 235
# 最优值： 0.7080646 扰动程度： 5.114362600873716 代数： 236
# 最优值： 0.70444906 扰动程度： 5.126767709465381 代数： 237
# 最优值： 0.7022605 扰动程度： 5.1531421744483135 代数： 238
# 最优值： 0.6993986 扰动程度： 5.129351679130466 代数： 239
# resume
# 最优值： 0.70607287 扰动程度： 5.039702480782687 代数： 240
# 最优值： 0.70581627 扰动程度： 5.032156365977829 代数： 241
# 最优值： 0.710631 扰动程度： 4.906089786706407 代数： 242
# 最优值： 0.71066666 扰动程度： 4.911146375843951 代数： 243
# 最优值： 0.7106129 扰动程度： 4.9154917067360575 代数： 244
# 最优值： 0.71556455 扰动程度： 4.8370868030687575 代数： 245
# 最优值： 0.7157591 扰动程度： 4.840174912644756 代数： 246
# 最优值： 0.7166243 扰动程度： 4.783393679000162 代数： 291
# 最优值： 0.71287286 扰动程度： 4.870821911981032 代数： 292
# 最优值： 0.70769316 扰动程度： 4.888442918118255 代数： 293
# 最优值： 0.70088804 扰动程度： 4.8870062107461685 代数： 294
# 最优值： 0.6990485 扰动程度： 4.896309982081659 代数： 295
# 最优值： 0.6937656 扰动程度： 4.995600804717395 代数： 296
# 最优值： 0.69026375 扰动程度： 5.035648229750079 代数： 297
# 最优值： 0.6827995 扰动程度： 5.072229279603041 代数： 298
# 最优值： 0.6810225 扰动程度： 5.10224577475663 代数： 299
# 最优值： 0.67685837 扰动程度： 5.201014880630085 代数： 300
# 最优值： 0.66643536 扰动程度： 5.205849322414468 代数： 301
# 最优值： 0.6628903 扰动程度： 5.293275090468269 代数： 302
# 最优值： 0.65973234 扰动程度： 5.339916734280207 代数： 303
# 最优值： 0.65271485 扰动程度： 5.276957274007891 代数： 304
# 最优值： 0.64857215 扰动程度： 5.352095774526652 代数： 305
# 最优值： 0.6407671 扰动程度： 5.4981194347805165 代数： 306
# 最优值： 0.6350719 扰动程度： 5.594018916908717 代数： 307
# 最优值： 0.63121545 扰动程度： 5.612196667829449 代数： 308
# 最优值： 0.6221006 扰动程度： 5.655756775341203 代数： 309
# 最优值： 0.6169551 扰动程度： 5.723354379061126 代数： 310
# 最优值： 0.6128769 扰动程度： 5.814043858563997 代数： 311
# 最优值： 0.60031366 扰动程度： 5.824449388344766 代数： 312
# 最优值： 0.5975873 扰动程度： 5.849666577246472 代数： 313
# resume
# 最优值： 0.598771 扰动程度： 5.842617041227278 代数： 314
# 最优值： 0.5980617 扰动程度： 5.83712065606633 代数： 315
# 最优值： 0.59805775 扰动程度： 5.843373337081454 代数： 316
# 最优值： 0.59144956 扰动程度： 5.9332318976070235 代数： 317
# 最优值： 0.59260654 扰动程度： 5.8921243330651 代数： 318
# 最优值： 0.59498477 扰动程度： 5.865851206710797 代数： 319
# 最优值： 0.5938929 扰动程度： 5.88238431911802 代数： 320
# 最优值： 0.6035567 扰动程度： 5.811532607883004 代数： 321
# 最优值： 0.6111088 扰动程度： 5.6721072806234485 代数： 322
# 最优值： 0.61821824 扰动程度： 5.635117857948001 代数： 323
# 最优值： 0.61880577 扰动程度： 5.575584636811092 代数： 324
# 最优值： 0.6261947 扰动程度： 5.5110099118049405 代数： 325
# 最优值： 0.63438785 扰动程度： 5.469997350031568 代数： 326
# 最优值： 0.6430645 扰动程度： 5.40903895149061 代数： 327
# 最优值： 0.65209866 扰动程度： 5.308172222348925 代数： 328
# 最优值： 0.6598944 扰动程度： 5.157524207048473 代数： 329
# 最优值： 0.668856 扰动程度： 5.108372836357964 代数： 330
# 最优值： 0.6786284 扰动程度： 5.036813131794284 代数： 331
# 最优值： 0.67459625 扰动程度： 5.0058870800400985 代数： 332
# 最优值： 0.6713859 扰动程度： 5.036395927310229 代数： 333
# 最优值： 0.6753379 扰动程度： 4.99052572026685 代数： 334
# 最优值： 0.6768249 扰动程度： 4.979678149250988 代数： 335
# 最优值： 0.6737306 扰动程度： 5.006152574981319 代数： 336
# 最优值： 0.68405825 扰动程度： 4.930096982453998 代数： 337
# 最优值： 0.6836848 扰动程度： 4.910771953540752 代数： 338
# 最优值： 0.6921858 扰动程度： 4.903024257797154 代数： 339
# 最优值： 0.698958 扰动程度： 4.862763978835416 代数： 340
# 最优值： 0.70873773 扰动程度： 4.7930711381928415 代数： 341
# 最优值： 0.70280474 扰动程度： 4.7822408443718185 代数： 342
# 最优值： 0.71098566 扰动程度： 4.745458693263418 代数： 343
# 最优值： 0.7181923 扰动程度： 4.653104345196717 代数： 344
# 最优值： 0.72672576 扰动程度： 4.636858315997368 代数： 345
# 最优值： 0.72744584 扰动程度： 4.577867677038185 代数： 346
# 最优值： 0.73679876 扰动程度： 4.514754572373442 代数： 347
# 最优值： 0.74590564 扰动程度： 4.499216536397623 代数： 348
# attack
# 最优值： 0.7258374 扰动程度： 4.572919116582271 代数： 349
# 最优值： 0.71568936 扰动程度： 4.627721756221281 代数： 350
# 最优值： 0.7089721 扰动程度： 4.681092956505438 代数： 351
# 最优值： 0.69624805 扰动程度： 4.740763241872549 代数： 352
# 最优值： 0.6946358 扰动程度： 4.790096678242441 代数： 353
# 最优值： 0.69028395 扰动程度： 4.879587523806846 代数： 354
# 最优值： 0.67894894 扰动程度： 4.951694005143242 代数： 355
# 最优值： 0.67746705 扰动程度： 4.942830806463094 代数： 356
# 最优值： 0.67497253 扰动程度： 5.036743532420347 代数： 357
# 最优值： 0.6727628 扰动程度： 4.994664644656708 代数： 358
# 最优值： 0.6566136 扰动程度： 5.082378071731537 代数： 359
# 最优值： 0.6483164 扰动程度： 5.155568001913126 代数： 360
# 最优值： 0.64329433 扰动程度： 5.226403365652998 代数： 361
# 最优值： 0.63543665 扰动程度： 5.301109832661989 代数： 362
# 最优值： 0.63321084 扰动程度： 5.326753543229658 代数： 363
# 最优值： 0.6341435 扰动程度： 5.2476935131045614 代数： 364
# 最优值： 0.62654525 扰动程度： 5.299893913294444 代数： 365
# 最优值： 0.624616 扰动程度： 5.363298117722529 代数： 366
# 最优值： 0.61256486 扰动程度： 5.34236448460586 代数： 367
# 最优值： 0.6062647 扰动程度： 5.4391576240961035 代数： 368
# 最优值： 0.60779345 扰动程度： 5.415904942892494 代数： 369
# 最优值： 0.6004406 扰动程度： 5.450689713118402 代数： 370
# 最优值： 0.59759414 扰动程度： 5.504900718087834 代数： 371
# 最优值： 0.5961525 扰动程度： 5.5948834385672015 代数： 372
# 最优值： 0.58543336 扰动程度： 5.580859713100323 代数： 373
# 最优值： 0.58428884 扰动程度： 5.593615619170218 代数： 374
# 最优值： 0.581311 扰动程度： 5.689677876027754 代数： 375
# 最优值： 0.57319075 扰动程度： 5.7094650409829555 代数： 376
# 最优值： 0.5638377 扰动程度： 5.763548590400083 代数： 377
# 最优值： 0.5589373 扰动程度： 5.769671600421237 代数： 378
# 最优值： 0.5593535 扰动程度： 5.779566247531728 代数： 379
# 最优值： 0.55943084 扰动程度： 5.770457982216697 代数： 380
# 最优值： 0.5560841 扰动程度： 5.826531223594626 代数： 381
# 最优值： 0.54721695 扰动程度： 5.861585670514779 代数： 382
# 最优值： 0.54468626 扰动程度： 5.936368085364455 代数： 383
# 最优值： 0.5380225 扰动程度： 5.959724490474416 代数： 384
# 最优值： 0.53382534 扰动程度： 6.037304043569443 代数： 385
# 最优值： 0.52820307 扰动程度： 6.007299334619384 代数： 386
# 最优值： 0.52469623 扰动程度： 6.0787433867061695 代数： 387
# 最优值： 0.519792 扰动程度： 6.051294860811744 代数： 388
# 最优值： 0.50922155 扰动程度： 6.093137195371184 代数： 389
# 最优值： 0.5112032 扰动程度： 6.158730826811994 代数： 390
# 最优值： 0.5052816 扰动程度： 6.110831743539687 代数： 391
# 最优值： 0.49879858 扰动程度： 6.178032512413552 代数： 392
# resume
# 最优值： 0.49565068 扰动程度： 6.202933087052425 代数： 393
# 最优值： 0.5041638 扰动程度： 6.120565300251234 代数： 394
# 最优值： 0.5062938 扰动程度： 6.10747732125794 代数： 395
# 最优值： 0.5127014 扰动程度： 6.082032371125093 代数： 396
# 最优值： 0.5186815 扰动程度： 6.020346546524907 代数： 397
# 最优值： 0.5222509 扰动程度： 5.983256012154576 代数： 398
# 最优值： 0.52457625 扰动程度： 5.98034531911938 代数： 399
# 最优值： 0.53160197 扰动程度： 5.907276168082153 代数： 400
# 最优值： 0.53677076 扰动程度： 5.868790797501702 代数： 401
# 最优值： 0.5405624 扰动程度： 5.824181074313701 代数： 402
# 最优值： 0.5422894 扰动程度： 5.808987890257278 代数： 403
# 最优值： 0.5434658 扰动程度： 5.794534621466979 代数： 404
# 最优值： 0.54676354 扰动程度： 5.788462943652475 代数： 405
# 最优值： 0.55473685 扰动程度： 5.760544430219905 代数： 406
# 最优值： 0.55985445 扰动程度： 5.702218483666528 代数： 407
# 最优值： 0.5616477 扰动程度： 5.653849602045533 代数： 408
# 最优值： 0.5680125 扰动程度： 5.576075585055641 代数： 409
# 最优值： 0.56681234 扰动程度： 5.576580972185953 代数： 410
# 最优值： 0.5726928 扰动程度： 5.530818826935647 代数： 411
# 最优值： 0.5753138 扰动程度： 5.515216742164968 代数： 412
# 最优值： 0.5841237 扰动程度： 5.4728653742352735 代数： 413
# 最优值： 0.58426785 扰动程度： 5.419754586342527 代数： 414
# 最优值： 0.5938058 扰动程度： 5.399472852467176 代数： 415
# 最优值： 0.5982676 扰动程度： 5.31543415366461 代数： 416
# 最优值： 0.59808373 扰动程度： 5.309252633296672 代数： 417
# 最优值： 0.60018545 扰动程度： 5.290921337436214 代数： 418
# 最优值： 0.6079427 扰动程度： 5.270838892772525 代数： 419
# 最优值： 0.61131793 扰动程度： 5.2253686342747665 代数： 420
# 最优值： 0.6210275 扰动程度： 5.143125384001789 代数： 421
# 最优值： 0.6232633 扰动程度： 5.15348706425701 代数： 422
# 最优值： 0.62096703 扰动程度： 5.159435301916526 代数： 423
# 最优值： 0.6282003 扰动程度： 5.081183842849327 代数： 424
# 最优值： 0.63091934 扰动程度： 5.067347636633597 代数： 425
# 最优值： 0.6346509 扰动程度： 5.040064364092126 代数： 426
# 最优值： 0.6326349 扰动程度： 5.033957898445041 代数： 427
# 最优值： 0.6293346 扰动程度： 5.043172383710609 代数： 428
# 最优值： 0.6346665 扰动程度： 5.014678914150137 代数： 429
# 最优值： 0.639271 扰动程度： 5.001349911405171 代数： 430
# 最优值： 0.64654624 扰动程度： 4.986450418946013 代数： 431
# attack
# 最优值： 0.6303357 扰动程度： 5.047540924929765 代数： 432
# 最优值： 0.62283975 扰动程度： 5.136384710315634 代数： 433
# 最优值： 0.6166413 扰动程度： 5.234849576530691 代数： 434
# 最优值： 0.6025929 扰动程度： 5.310081142175926 代数： 435
# 最优值： 0.5955693 扰动程度： 5.334036576471685 代数： 436
# 最优值： 0.59098357 扰动程度： 5.421937066886661 代数： 437
# 最优值： 0.5916569 扰动程度： 5.375256478306261 代数： 438
# 最优值： 0.5783645 扰动程度： 5.431281339418935 代数： 439
# 最优值： 0.5765171 扰动程度： 5.445483458036203 代数： 440
# 最优值： 0.56922483 扰动程度： 5.540171068666388 代数： 441
# 最优值： 0.56609493 扰动程度： 5.625332855221125 代数： 442
# 最优值： 0.5585222 扰动程度： 5.719661615652911 代数： 443
# 最优值： 0.55528754 扰动程度： 5.679999028918866 代数： 444
# 最优值： 0.5312839 扰动程度： 5.767721194913703 代数： 445
# 最优值： 0.51918775 扰动程度： 5.856872699112161 代数： 446
# 最优值： 0.51804143 扰动程度： 5.8665350991578356 代数： 447
# 最优值： 0.5218025 扰动程度： 5.8366838795020275 代数： 448
# 最优值： 0.5179452 扰动程度： 5.870182093091361 代数： 449
# 最优值： 0.51681167 扰动程度： 5.908689444268067 代数： 450
# 最优值： 0.5147533 扰动程度： 5.949752304734987 代数： 451
# 最优值： 0.50991076 扰动程度： 6.040335911100636 代数： 452
# 最优值： 0.49962768 扰动程度： 6.110493971433067 代数： 453
# 最优值： 0.48566338 扰动程度： 6.1976945589578145 代数： 454
# 最优值： 0.48918256 扰动程度： 6.175066435426194 代数： 455
# 最优值： 0.48129976 扰动程度： 6.274200574874422 代数： 456
# 最优值： 0.47816858 扰动程度： 6.276262672590972 代数： 457
# 最优值： 0.47076127 扰动程度： 6.3529503960195735 代数： 458
# 最优值： 0.46841812 扰动程度： 6.326110448186348 代数： 459
# 最优值： 0.45949042 扰动程度： 6.416635546860507 代数： 460
# 最优值： 0.44569242 扰动程度： 6.468362426314494 代数： 461
# 最优值： 0.44235706 扰动程度： 6.51579534295448 代数： 462
# 最优值： 0.4386241 扰动程度： 6.569924722675127 代数： 463
# 最优值： 0.43330988 扰动程度： 6.666240865752242 代数： 464
# 最优值： 0.4303041 扰动程度： 6.683774930231285 代数： 465
# 最优值： 0.42846668 扰动程度： 6.691610685555558 代数： 466
# 最优值： 0.42287305 扰动程度： 6.694234541526194 代数： 467
# 最优值： 0.41336596 扰动程度： 6.784153931911304 代数： 468
  0.00000000e+00,
        0.00000000e+00,  0.00000000e+00,  5.61713280e-04, -0.00000000e+00,
        0.00000000e+00,  5.40406741e-02,  0.00000000e+00,  0.00000000e+00,
        5.46063028e-03,  1.53739314e-02,  0.00000000e+00,  3.35924544e-03,
        0.00000000e+00,  6.05677739e-05,  2.16842708e-03,  3.41250353e-03,
        0.00000000e+00,  0.00000000e+00,  2.97435142e-02,  1.68249069e-03,
        0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -2.38449227e-02,
       -5.21959898e-05, -2.31468904e-02,  0.00000000e+00,  0.00000000e+00,
        5.40254759e-04, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
        1.21554002e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
        0.00000000e+00,  1.37694629e-01,  0.00000000e+00,  0.00000000e+00,
        1.82122309e-02,  9.23621013e-05,  5.90423432e-03,  1.09421432e-03,
        1.29115106e-01,  1.16387775e-01,  3.49655997e-04,  0.00000000e+00,
        0.00000000e+00,  0.00000000e+00,  1.18940318e-04,  1.79455656e-01,
        7.45207254e-02,  3.09738418e-04,  1.60013815e-02,  0.00000000e+00,
        6.69385775e-05,  0.00000000e+00,  0.00000000e+00,  4.31482036e-04,
        0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
        1.82737511e-02,  6.24068276e-02,  6.52179969e-03,  0.00000000e+00])

# %%
BEST = BEST_X + x_test[0]
plt.imshow(BEST.reshape(28,28),cmap='gray')
plt.show()

# %%
result=model.predict(BEST_X.reshape(1,784))
result[0]
# Out:
# array([0.03606191, 0.13325453, 0.30351505, 0.14268604, 0.03217717,
#        0.18159828, 0.06348677, 0.01640903, 0.07245255, 0.01835869],
#       dtype=float32)

# %%
# test
count = 0
for i in range(784):
    if BEST_X[i] != 0:
        count+=1
print(count)
# Out:
# 498

# %%
# test
count = 0
for i in range(784):
    if BEST_X[i] > 0.8:
        count+=1
print(count)
# Out:
# 0

# %%
#过滤（低强度）
import copy
x_f = copy.deepcopy(BEST_X)
for i in range(784):
    if abs(x_f[i]) < 0.2:
        x_f[i] = 0
f = x_f+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
result=model.predict(f.reshape(1,784))
print("置信度：", result[0][7])
print(result[0])
print("扰动程度：",Dis(x_f))
# Out:
# 置信度： 0.79100835
# [1.5174575e-03 6.5535348e-04 4.4565573e-02 1.5166000e-01 1.2409961e-04
#  4.1875131e-03 1.3115628e-05 7.9100835e-01 2.5698482e-03 3.6986568e-03]
# 扰动程度： 5.808045297534583

# %%
#过滤（高强度）
import copy
x_F = copy.deepcopy(BEST_X)
for i in range(784):
    if abs(x_F[i]) > 0.5:
        x_F[i] = 0
F = x_F+x_test[0]
plt.imshow(F.reshape(28,28),cmap='gray')
plt.show()
result=model.predict(F.reshape(1,784))
print("置信度：", result[0][7])
print(result[0])
print("扰动程度：",Dis(x_F))
# Out:
# 置信度： 0.7140484
# [3.5013091e-03 7.0029777e-04 8.5273638e-02 1.8356721e-01 1.1966820e-04
#  6.3261571e-03 2.0771509e-05 7.1404839e-01 3.2437495e-03 3.1988441e-03]
# 扰动程度： 5.399337470712778

# %%
# 改变坐标减小置信度（过滤0.2）
import copy
x_t = copy.deepcopy(x_f)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代: 1
# 置信度： 0.79081285
# 迭代: 2
# 置信度： 0.78750575
# 迭代: 3
# 置信度： 0.7869196
# 迭代: 4
# 置信度： 0.7822701
# 迭代: 5
# 置信度： 0.78187114
# 迭代: 6
# 置信度： 0.777245
# 迭代: 7
# 置信度： 0.7769792
# 迭代: 8
# 置信度： 0.77427053
# 迭代: 9
# 置信度： 0.7742648
# 迭代: 10
# 置信度： 0.77287626
# 迭代: 11
# 置信度： 0.7688211
# 迭代: 12
# 置信度： 0.76710916
# 迭代: 13
# 置信度： 0.76175636
# 迭代: 14
# 置信度： 0.754947
# 迭代: 15
# 置信度： 0.73712313
# 迭代: 16
# 置信度： 0.73679423
# 迭代: 17
# 置信度： 0.7302526
# 迭代: 18
# 置信度： 0.7288987
# 迭代: 19
# 置信度： 0.72669345
# 迭代: 20
# 置信度： 0.7041881
# 迭代: 21
# 置信度： 0.69990194
# 迭代: 22
# 置信度： 0.69171655
# 迭代: 23
# 置信度： 0.69031096
# 迭代: 24
# 置信度： 0.6852583
# 迭代: 25
# 置信度： 0.6840442
# 迭代: 26
# 置信度： 0.672793
# 迭代: 27
# 置信度： 0.6632727
# 迭代: 28
# 置信度： 0.6593912
# 迭代: 29
# 置信度： 0.65689915
# 迭代: 30
# 置信度： 0.642851
# 迭代: 31
# 置信度： 0.6423891
# 迭代: 32
# 置信度： 0.6416772
# 迭代: 33
# 置信度： 0.6382753
# 迭代: 34
# 置信度： 0.6347022
# 迭代: 35
# 置信度： 0.6346574
# 迭代: 36
# 置信度： 0.6339686
# 迭代: 37
# 置信度： 0.63303316
# 迭代: 38
# 置信度： 0.6291769
# 迭代: 39
# 置信度： 0.6288673
# 迭代: 40
# 置信度： 0.6225137
# 迭代: 41
# 置信度： 0.6176364
# 迭代: 42
# 置信度： 0.61705863
# 迭代: 43
# 置信度： 0.611814
# 迭代: 44
# 置信度： 0.6064441
# 迭代: 45
# 置信度： 0.5942284
# 迭代失败
# 最终置信度： 0.5942284
# 最终扰动程度： 5.808045297534582
# [1.0967220e-03 9.6672133e-04 4.5148227e-02 3.4004280e-01 1.6902824e-04
#  4.2748246e-03 1.2764148e-05 5.9422839e-01 6.3656499e-03 7.6948670e-03]

# %%
# 改变坐标减小置信度（过滤0.5）
import copy
x_t = copy.deepcopy(x_F)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代失败
# 最终置信度： 0.7140484
# 最终扰动程度： 5.399337470712778
# [3.5013091e-03 7.0029777e-04 8.5273638e-02 1.8356721e-01 1.1966820e-04
#  6.3261571e-03 2.0771509e-05 7.1404839e-01 3.2437495e-03 3.1988441e-03]

# %%
# 改变坐标减小置信度
import copy
x_t = copy.deepcopy(BEST_X)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代失败
# 最终置信度： 0.39767227
# 最终扰动程度： 7.0038201815486
# [3.7777259e-03 1.0443135e-03 1.1682559e-01 4.5660120e-01 1.5665211e-04
#  1.2439688e-02 3.2627453e-05 3.9767227e-01 7.4698036e-03 3.9801179e-03]
