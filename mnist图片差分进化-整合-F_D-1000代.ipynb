# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
from keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import load_model,Model
import random
import math
import threading
import time

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
import copy
x_tmp = copy.deepcopy(x_test[0])

# %%
#产生扰动种群
x_des = []
for r in range(100):
    for i in range(28):
        for j in range(28):
            x= random.randint(0,10000)/10000
            if x <= 0.1:
                u = x_tmp[i,j] # 期望值μ
                sig = math.sqrt(0.2) # 标准差δ
                x_ = random.uniform(u - 3*sig, u + 3*sig)
                y_sig = np.exp(-(x_ - u) ** 2 /(2* sig **2))/(math.sqrt(2*math.pi)*sig)
                y_= random.randint(0,10000)/10000
                if y_ <= y_sig:
                    if x_test[0][i,j] <= 127:
                        x_tmp[i,j] += 255*0.1
                    elif x_test[0][i,j] > 127 and x_test[0][i,j] < 229:
                        y = random.randint(0,10000)/10000
                        if y <= 0.5:
                            x_tmp[i,j] += 255*0.1
                        else:
                            x_tmp[i,j] -= 255*0.1
                    elif x_test[0][i,j] >= 229:
                        x_tmp[i,j] -= 255*0.1
    x_t = x_tmp/255-x_test[0]/255
    #x_des.append(np.array (x_t.reshape(1,784)))
    x_des.append(np.array(x_t.reshape(1,784)))
    plt.imshow(x_tmp,cmap='gray')
    plt.show()
    x_tmp = copy.deepcopy(x_test[0])

# %%
x_train = x_train.reshape(60000,784)    # 将图片摊平，变成向量

# %%
x_test = x_test.reshape(10000,784)     # 对测试集进行同样的处理

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
model = load_model('mnist_model.h5')

# %%
def Func(x):
    x_F = x[:]+x_test[0]
    result=model.predict(x_F.reshape(1,784))
    return result[0][7]

# %%
def Dis(x):   # 扰动值
    res = 0
    for i in range(784):
        l = x[i]
        res += l**2
    return res

# %%
# 攻击模块
class Atk(threading.Thread):

    def __init__(self,cond,name):
        #threading.Thread.__init__(self)
        super(Atk, self).__init__()
        self.cond = cond
        self.name = name

    def run(self):
        self.cond.acquire()
        print(self.name)
        global F
        global D
        global BEST_X
        global GENERATION
        #while GENERATION < MAX_GENERATION:
        while Func(BEST_X) >= 0.35 or Dis(BEST_X) >= 6.5:
        #for t in range(5):
            #print(Func(BEST_X))
            DB = Dis(BEST_X)    # 存储上一代的扰动程度
            # 变异
            for i in range(N):
                r = np.random.randint(1, N, 2)
                V[i, :] = BEST_X + SIGMA * (X[r[0], :] - X[r[1], :])
                for j in range(784):
                    if V[i, j] > 1:
                        #print(V[i, j])
                        V[i, j] = 1-(V[i, j]-1)
                        #print(V[i, j])
                    elif V[i, j] <= 1:
                        if V[i, j] + x_test[0][j] > 1:
                            # V +t = 1-(V+t-1)
                            V[i, j] = 1-(V[i, j]+2*x_test[0][j]-1)
                            #print(V[i, j])
                        elif V[i, j] + x_test[0][j] < 0:
                            V[i, j] = -x_test[0][j]
            # print(V)
            # 交叉操作
            for i in range(N):
                jRand = np.floor(np.random.random() * L)
                for j in range(L):
                    # 至少有一个分量对U[i,j]作出了贡献
                    # CR调小 有利于往BEST_X的方向进化
                    if np.random.random() > CR or j == jRand:
                        U[i, j] = X[i, j]
                    else:
                        U[i, j] = V[i, j]
                    #if np.random.random() < CR or j == jRand:
                        #U[i, j] = V[i, j]
                    #else:
                        #U[i, j] = X[i, j]
            # 计算适应度值+选择操作
            for i in range(N):
                FITS[i] = Func(X[i])
                FITS_U[i] = Func(U[i])
                DIS[i] = Dis(X[i])
                DIS_U[i] = Dis(U[i])
                
                D_ = DIS_U[i] - DB
                # 变异的种子表现更好
                if FITS[i] >= FITS_U[i] and D_ < 0.1:
                    X[i, :] = U[i, :]
                    FITS[i] = FITS_U[i]
                    if FITS_U[i] < Func(BEST_X) and D_ < 0.1:
                        BEST_X = U[i, :]
            GENERATION += 1
            
            print("最优值：", Func(BEST_X),"扰动程度：",Dis(BEST_X),"代数：",GENERATION)
            
            
            if Func(BEST_X) <= F:
                print("resume")
                if D <= 7.5:
                    D += 0.4 
                self.cond.notify()  # 唤醒一个挂起的线程
                self.cond.wait()
        self.cond.release()


# 恢复模块
class Re(threading.Thread):

    def __init__(self,cond,name):
        #threading.Thread.__init__(self)
        super(Re, self).__init__()
        self.cond = cond
        self.name = name

    def run(self):
        #time.sleep(1)
        self.cond.acquire()
        self.cond.wait()
        #print(self.name)
        global F
        global D
        global BEST_X
        global GENERATION
        #while GENERATION < MAX_GENERATION:
        while Func(BEST_X) >= 0.35 or Dis(BEST_X) >= 6.5:
        #for t in range(5):
            #print(Func(BEST_X))
            FB = Func(BEST_X)    # 存储上一代的置信度
            # 变异
            for i in range(N):
                r = np.random.randint(1, N, 2)
                V[i, :] = BEST_X + SIGMA * (X[r[0], :] - X[r[1], :])
                for j in range(784):
                    if V[i, j] > 1:
                        #print(V[i, j])
                        V[i, j] = 1-(V[i, j]-1)
                        #print(V[i, j])
                    elif V[i, j] <= 1:
                        if V[i, j] + x_test[0][j] > 1:
                            # V +t = 1-(V+t-1)
                            V[i, j] = 1-(V[i, j]+2*x_test[0][j]-1)
                            #print(V[i, j])
                        elif V[i, j] + x_test[0][j] < 0:
                            V[i, j] = -x_test[0][j]
            # print(V)
            # 交叉操作
            for i in range(N):
                jRand = np.floor(np.random.random() * L)
                for j in range(L):
                    # 至少有一个分量对U[i,j]作出了贡献
                    # CR调小 有利于往BEST_X的方向进化
                    if np.random.random() > CR or j == jRand:
                        U[i, j] = X[i, j]
                    else:
                        U[i, j] = V[i, j]
                    #if np.random.random() < CR or j == jRand:
                        #U[i, j] = V[i, j]
                    #else:
                        #U[i, j] = X[i, j]
            # 计算适应度值+选择操作
            for i in range(N):
                FITS[i] = Func(X[i])
                FITS_U[i] = Func(U[i])
                DIS[i] = Dis(X[i])
                DIS_U[i] = Dis(U[i]) 
                F_ = FITS_U[i] - FB
                
                # 变异的种子表现更好
                #if FITS[i] >= FITS_U[i] and DIS[i] >= DIS_U[i]:
                if DIS[i] >= DIS_U[i] and F_ < 0.01:
                    X[i, :] = U[i, :]
                    FITS[i] = FITS_U[i]
                    if DIS_U[i] < Dis(BEST_X) and F_ < 0.01:
                        BEST_X = U[i, :]
            GENERATION += 1
            #print(F_)
            print("最优值：", Func(BEST_X),"扰动程度：",Dis(BEST_X),"代数：",GENERATION)
            
            
            if Dis(BEST_X) <= D:
                print("attack")
                if F >= 0.2:
                    F -= 0.1
                self.cond.notify()
                self.cond.wait()
        self.cond.release()

# %%
#MAX_GENERATION = 500  # 最大迭代次数
GENERATION = 0  # 当前代数
L = 784  # 种子的维度
N = 100  # 种群规模
SIGMA = 0.333  # 缩放因子
CR = 0.1  # 交叉概率
F = 0.8   #置信度参数
D = 3.0   #扰动参数
cond = threading.Condition()
atk = Atk(cond, "attack")
re = Re(cond, "resume")

GENERATION = 0  # 当前代数
BEST_X = 0
FITS = np.zeros(N)
FITS_U = np.zeros(N)
DIS = np.zeros(N)
DIS_U = np.zeros(N)
V = np.zeros((N, L))
U = np.zeros((N, L))
# 1、初始化
X = np.concatenate(x_des, axis=0)
# 找出随机生成的最好的种子
for i in range(N):
    FITS[i] = Func(X[i])
# 找出最好的种子 适应度值最小
BEST_X = X[np.argmin(FITS)]
re.start()
atk.start()

#re.join()
#atk.join()
if Func(BEST_X) < 0.4:
    BEST_F = BEST_X+x_test[0]
    #print(BEST_X_F)
    plt.imshow(BEST_F.reshape(28,28),cmap='gray')
    plt.show()
    #break
# Out:
# attack
# 最优值： 0.9964426 扰动程度： 0.35157119377162654 代数： 1
# 最优值： 0.9964104 扰动程度： 0.3548556568858134 代数： 2
# 最优值： 0.9963594 扰动程度： 0.36457272119109024 代数： 3
# 最优值： 0.99634355 扰动程度： 0.36563855164091724 代数： 4
# 最优值： 0.9962908 扰动程度： 0.4336352492260999 代数： 5
# 最优值： 0.9962041 扰动程度： 0.3894149610859538 代数： 6
# 最优值： 0.9961443 扰动程度： 0.4231584693715259 代数： 7
# 最优值： 0.99603087 扰动程度： 0.3859303207396293 代数： 8
# 最优值： 0.99600005 扰动程度： 0.371420035113887 代数： 9
# 最优值： 0.9959 扰动程度： 0.45289747947039466 代数： 10
# 最优值： 0.9957581 扰动程度： 0.43575378551419786 代数： 11
# 最优值： 0.9956169 扰动程度： 0.5122620442064488 代数： 12
# 最优值： 0.9954674 扰动程度： 0.4322007252554511 代数： 13
# 最优值： 0.9953218 扰动程度： 0.44215418616206725 代数： 14
# 最优值： 0.9949551 扰动程度： 0.4786166885427142 代数： 15
# 最优值： 0.99493957 扰动程度： 0.4850784830508511 代数： 16
# 最优值： 0.99487925 扰动程度： 0.4476200484987297 代数： 17
# 最优值： 0.9947897 扰动程度： 0.49585036088918777 代数： 18
# 最优值： 0.99437416 扰动程度： 0.5655502025190695 代数： 19
# 最优值： 0.99434954 扰动程度： 0.5700437569906878 代数： 20
# 最优值： 0.99406 扰动程度： 0.6149185915913813 代数： 21
# 最优值： 0.9940409 扰动程度： 0.6230890061997296 代数： 22
# 最优值： 0.99377304 扰动程度： 0.7125628009054376 代数： 23
# 最优值： 0.9936812 扰动程度： 0.7217947818253829 代数： 24
# 最优值： 0.99361646 扰动程度： 0.747185412600987 代数： 25
# 最优值： 0.9931075 扰动程度： 0.7770364520489963 代数： 26
# 最优值： 0.99299 扰动程度： 0.7888566028637033 代数： 27
# 最优值： 0.9930541 扰动程度： 0.7799653185766299 代数： 28
# 最优值： 0.99287075 扰动程度： 0.7748541054303651 代数： 29
# 最优值： 0.99244726 扰动程度： 0.8202884420972522 代数： 30
# 最优值： 0.99218035 扰动程度： 0.8454387822229784 代数： 31
# 最优值： 0.99156487 扰动程度： 0.9409476532734147 代数： 32
# 最优值： 0.9915803 扰动程度： 0.8914756427524481 代数： 33
# 最优值： 0.99140114 扰动程度： 0.9093733050232654 代数： 34
# 最优值： 0.9911389 扰动程度： 0.9482947212800396 代数： 35
# 最优值： 0.9909525 扰动程度： 0.9648270160847618 代数： 36
# 最优值： 0.99059945 扰动程度： 0.9528592621941918 代数： 37
# 最优值： 0.9905608 扰动程度： 0.967067957516681 代数： 38
# 最优值： 0.99024135 扰动程度： 1.0066349090832099 代数： 39
# 最优值： 0.99005324 扰动程度： 1.0235164919454776 代数： 40
# 最优值： 0.98954076 扰动程度： 1.1075882108208257 代数： 41
# 最优值： 0.9895051 扰动程度： 0.8945094233031625 代数： 42
# 最优值： 0.98964745 扰动程度： 0.8618757917798431 代数： 43
# 最优值： 0.9894308 扰动程度： 0.9030469080094723 代数： 44
# 最优值： 0.989344 扰动程度： 0.9490888223705283 代数： 45
# 最优值： 0.98884946 扰动程度： 0.9695639277897329 代数： 46
# 最优值： 0.9884447 扰动程度： 1.0396960951997585 代数： 47
# 最优值： 0.9879921 扰动程度： 1.1193050567051563 代数： 48
# 最优值： 0.9880877 扰动程度： 1.108043542821194 代数： 49
# 最优值： 0.9881196 扰动程度： 1.1124492679016451 代数： 50
# 最优值： 0.9880525 扰动程度： 1.2035670310206241 代数： 51
# 最优值： 0.98712265 扰动程度： 1.1675463164731121 代数： 52
# 最优值： 0.9868513 扰动程度： 1.1305030900146058 代数： 53
# 最优值： 0.9867352 扰动程度： 1.1810397768130618 代数： 54
# 最优值： 0.98647875 扰动程度： 1.2748499611094837 代数： 55
# 最优值： 0.98631305 扰动程度： 1.2758218750005426 代数： 56
# 最优值： 0.9861 扰动程度： 1.2910198429977688 代数： 57
# 最优值： 0.98559314 扰动程度： 1.2857972890905964 代数： 58
# 最优值： 0.9853076 扰动程度： 1.315462643449846 代数： 59
# 最优值： 0.9841851 扰动程度： 1.3357149563239874 代数： 60
# 最优值： 0.9840756 扰动程度： 1.3591821201231604 代数： 61
# 最优值： 0.9838741 扰动程度： 1.4443759581203677 代数： 62
# 最优值： 0.9833592 扰动程度： 1.482872563130011 代数： 63
# 最优值： 0.9818941 扰动程度： 1.5765427627936306 代数： 64
# 最优值： 0.98191077 扰动程度： 1.587831755491967 代数： 65
# 最优值： 0.9812794 扰动程度： 1.6387059703536015 代数： 66
# 最优值： 0.9807555 扰动程度： 1.6869894666149183 代数： 67
# 最优值： 0.98055184 扰动程度： 1.7753364050548321 代数： 68
# 最优值： 0.9802337 扰动程度： 1.7151661568361967 代数： 69
# 最优值： 0.979354 扰动程度： 1.7878118428851855 代数： 70
# 最优值： 0.9786735 扰动程度： 1.85676562760796 代数： 71
# 最优值： 0.97823596 扰动程度： 1.8761635769239566 代数： 72
# 最优值： 0.97708935 扰动程度： 1.9107620333609017 代数： 73
# 最优值： 0.97711813 扰动程度： 1.9003294608898036 代数： 74
# 最优值： 0.97595245 扰动程度： 1.9121775825712988 代数： 75
# 最优值： 0.9761836 扰动程度： 1.9103746241483128 代数： 76
# 最优值： 0.9756034 扰动程度： 1.9395401990015884 代数： 77
# 最优值： 0.9739749 扰动程度： 1.9692317011206222 代数： 78
# 最优值： 0.9736447 扰动程度： 2.0540464158572034 代数： 79
# 最优值： 0.97316736 扰动程度： 2.100762409395867 代数： 80
# 最优值： 0.9729006 扰动程度： 2.1126550412264615 代数： 81
# 最优值： 0.9722713 扰动程度： 2.1952283590815997 代数： 82
# 最优值： 0.97097373 扰动程度： 2.280017524177996 代数： 83
# 最优值： 0.9694146 扰动程度： 2.321768795348844 代数： 84
# 最优值： 0.96915126 扰动程度： 2.3530377798379614 代数： 85
# 最优值： 0.96882087 扰动程度： 2.258407248409824 代数： 86
# 最优值： 0.96825534 扰动程度： 2.3104048730949294 代数： 87
# 最优值： 0.96706736 扰动程度： 2.2898214165013107 代数： 88
# 最优值： 0.96635276 扰动程度： 2.2446981067651888 代数： 89
# 最优值： 0.9656092 扰动程度： 2.3532548948238743 代数： 90
# 最优值： 0.96545935 扰动程度： 2.405459301200286 代数： 91
# 最优值： 0.96500754 扰动程度： 2.4345597501918603 代数： 92
# 最优值： 0.96469504 扰动程度： 2.5282108594039543 代数： 93
# 最优值： 0.9629226 扰动程度： 2.4030513533610156 代数： 94
# 最优值： 0.9633158 扰动程度： 2.4134715593716995 代数： 95
# 最优值： 0.9621701 扰动程度： 2.439545871367367 代数： 96
# 最优值： 0.9620782 扰动程度： 2.4446756345930956 代数： 97
# 最优值： 0.9621985 扰动程度： 2.4483394822273383 代数： 98
# 最优值： 0.9616026 扰动程度： 2.4446319309093214 代数： 99
# 最优值： 0.9607034 扰动程度： 2.554052748621592 代数： 100
# 最优值： 0.959236 扰动程度： 2.546151316217415 代数： 101
# 最优值： 0.95780647 扰动程度： 2.6109118085607506 代数： 102
# 最优值： 0.95684725 扰动程度： 2.6306932371461738 代数： 103
# 最优值： 0.9569851 扰动程度： 2.6308057103626643 代数： 104
# 最优值： 0.9542142 扰动程度： 2.702285380124755 代数： 105
# 最优值： 0.9541494 扰动程度： 2.6765548271495305 代数： 106
# 最优值： 0.9535634 扰动程度： 2.7328628604031655 代数： 107
# 最优值： 0.9504288 扰动程度： 2.758429578578424 代数： 108
# 最优值： 0.9494107 扰动程度： 2.781320686310099 代数： 109
# 最优值： 0.9483616 扰动程度： 2.867663266220122 代数： 110
# 最优值： 0.94701695 扰动程度： 2.8398855607660076 代数： 111
# 最优值： 0.9453241 扰动程度： 2.91704645497689 代数： 112
# 最优值： 0.94446504 扰动程度： 2.9438337575220825 代数： 113
# 最优值： 0.943842 扰动程度： 2.9271644045694676 代数： 114
# 最优值： 0.94386744 扰动程度： 2.9335519114836517 代数： 115
# 最优值： 0.9432518 扰动程度： 3.022635321237545 代数： 116
# 最优值： 0.9425976 扰动程度： 2.992890753575849 代数： 117
# 最优值： 0.9394923 扰动程度： 3.029518571692991 代数： 118
# 最优值： 0.9390069 扰动程度： 3.1071140601552765 代数： 119
# 最优值： 0.9373351 扰动程度： 3.1242564554928345 代数： 120
# 最优值： 0.9360733 扰动程度： 3.214824991233408 代数： 121
# 最优值： 0.9350316 扰动程度： 3.1515320593539617 代数： 122
# 最优值： 0.93380433 扰动程度： 3.1817217579880475 代数： 123
# 最优值： 0.931731 扰动程度： 3.2581879259975435 代数： 124
# 最优值： 0.93106896 扰动程度： 3.1287502245561427 代数： 125
# 最优值： 0.9294062 扰动程度： 3.153035508925211 代数： 126
# 最优值： 0.92893994 扰动程度： 3.200978649421491 代数： 127
# 最优值： 0.92793596 扰动程度： 3.2229191333390204 代数： 128
# 最优值： 0.9263674 扰动程度： 3.277144676462555 代数： 129
# 最优值： 0.9263528 扰动程度： 3.304354906160526 代数： 130
# 最优值： 0.9278669 扰动程度： 3.3127575612519906 代数： 131
# 最优值： 0.92093784 扰动程度： 3.395508014113185 代数： 132
# 最优值： 0.92033964 扰动程度： 3.3799392734837403 代数： 133
# 最优值： 0.9200012 扰动程度： 3.4746464853007164 代数： 134
# 最优值： 0.91628367 扰动程度： 3.4810093237055257 代数： 135
# 最优值： 0.9164487 扰动程度： 3.5023390027708357 代数： 136
# 最优值： 0.91283184 扰动程度： 3.545640631226129 代数： 137
# 最优值： 0.91141075 扰动程度： 3.5722521336145396 代数： 138
# 最优值： 0.9103904 扰动程度： 3.588217705562642 代数： 139
# 最优值： 0.9110609 扰动程度： 3.6448552864676667 代数： 140
# 最优值： 0.909764 扰动程度： 3.686780684912585 代数： 141
# 最优值： 0.9077257 扰动程度： 3.6078535226057897 代数： 142
# 最优值： 0.9075605 扰动程度： 3.6180696081006136 代数： 143
# 最优值： 0.9045336 扰动程度： 3.6615552970053757 代数： 144
# 最优值： 0.9041497 扰动程度： 3.639146360074609 代数： 145
# 最优值： 0.9042468 扰动程度： 3.672725970254341 代数： 146
# 最优值： 0.9027623 扰动程度： 3.7000273690306456 代数： 147
# 最优值： 0.8998586 扰动程度： 3.78746507840946 代数： 148
# 最优值： 0.8963908 扰动程度： 3.8282004545434374 代数： 149
# 最优值： 0.89612937 扰动程度： 3.815878136667486 代数： 150
# 最优值： 0.8938344 扰动程度： 3.89798755539767 代数： 151
# 最优值： 0.8932284 扰动程度： 3.9253762551961757 代数： 152
# 最优值： 0.88987577 扰动程度： 3.9222602432398386 代数： 153
# 最优值： 0.8881006 扰动程度： 3.8675663721773677 代数： 154
# 最优值： 0.8871207 扰动程度： 3.8949082473502643 代数： 155
# 最优值： 0.88634527 扰动程度： 3.91158295971376 代数： 156
# 最优值： 0.88180506 扰动程度： 3.9338898170045478 代数： 157
# 最优值： 0.88415474 扰动程度： 3.997937423892527 代数： 158
# 最优值： 0.87733775 扰动程度： 4.081306944015711 代数： 159
# 最优值： 0.87633663 扰动程度： 4.1461885739109015 代数： 160
# 最优值： 0.8746643 扰动程度： 4.207604931709276 代数： 161
# 最优值： 0.8695864 扰动程度： 4.234200197538406 代数： 162
# 最优值： 0.8656124 扰动程度： 4.3090836347956865 代数： 163
# 最优值： 0.86439306 扰动程度： 4.367727531807863 代数： 164
# 最优值： 0.86296594 扰动程度： 4.3876960011188695 代数： 165
# 最优值： 0.8621192 扰动程度： 4.40585709866238 代数： 166
# 最优值： 0.85827744 扰动程度： 4.496258524580782 代数： 167
# 最优值： 0.85571575 扰动程度： 4.552718541181203 代数： 168
# 最优值： 0.8565262 扰动程度： 4.5340957469359 代数： 169
# 最优值： 0.85329825 扰动程度： 4.608568403486332 代数： 170
# 最优值： 0.8465824 扰动程度： 4.625518789942155 代数： 171
# 最优值： 0.8439151 扰动程度： 4.6653508371654935 代数： 172
# 最优值： 0.84382325 扰动程度： 4.750080110682276 代数： 173
# 最优值： 0.83502334 扰动程度： 4.759657813173091 代数： 174
# 最优值： 0.83471006 扰动程度： 4.742633967457072 代数： 175
# 最优值： 0.8329658 扰动程度： 4.7381166340488745 代数： 176
# 最优值： 0.82890254 扰动程度： 4.7159228640787 代数： 177
# 最优值： 0.82448596 扰动程度： 4.767374747075502 代数： 178
# 最优值： 0.8230836 扰动程度： 4.817144471538668 代数： 179
# 最优值： 0.82300615 扰动程度： 4.816348752043654 代数： 180
# 最优值： 0.8174135 扰动程度： 4.796696767996211 代数： 181
# 最优值： 0.81872445 扰动程度： 4.762138090069273 代数： 182
# 最优值： 0.8178096 扰动程度： 4.799786006980535 代数： 183
# 最优值： 0.8172712 扰动程度： 4.809343617243067 代数： 184
# 最优值： 0.8144365 扰动程度： 4.896507266511917 代数： 185
# 最优值： 0.80661726 扰动程度： 4.9460404871300625 代数： 186
# 最优值： 0.80897087 扰动程度： 4.998024401449163 代数： 187
# 最优值： 0.8084644 扰动程度： 4.975649838316551 代数： 188
# 最优值： 0.80051774 扰动程度： 4.987007861905254 代数： 189
# 最优值： 0.7991247 扰动程度： 5.041958706388382 代数： 190
# resume
# 最优值： 0.80902094 扰动程度： 4.858063859027033 代数： 191
# 最优值： 0.81675303 扰动程度： 4.820663425379679 代数： 192
# 最优值： 0.8244581 扰动程度： 4.6640702457673635 代数： 193
# 最优值： 0.8290269 扰动程度： 4.603751792054691 代数： 194
# 最优值： 0.83398455 扰动程度： 4.571070371107095 代数： 195
# 最优值： 0.8436555 扰动程度： 4.422727237814359 代数： 196
# 最优值： 0.8424691 扰动程度： 4.37543019195239 代数： 197
# 最优值： 0.8426282 扰动程度： 4.285003351174634 代数： 198
# 最优值： 0.85142106 扰动程度： 4.218453915358465 代数： 199
# 最优值： 0.85958815 扰动程度： 4.176542351909392 代数： 200
# 最优值： 0.8617938 扰动程度： 4.078263377900828 代数： 201
# 最优值： 0.86336064 扰动程度： 4.065612619026451 代数： 202
# 最优值： 0.86975014 扰动程度： 3.8454844226914826 代数： 203
# 最优值： 0.8657922 扰动程度： 3.8912169146303373 代数： 204
# 最优值： 0.8710049 扰动程度： 3.8268167098586603 代数： 205
# 最优值： 0.8721262 扰动程度： 3.8075055569154754 代数： 206
# 最优值： 0.8760844 扰动程度： 3.7910185959937857 代数： 207
# 最优值： 0.88003093 扰动程度： 3.727766196726154 代数： 208
# 最优值： 0.88623345 扰动程度： 3.6416974994371456 代数： 209
# 最优值： 0.89163345 扰动程度： 3.5780206310051397 代数： 210
# 最优值： 0.8873613 扰动程度： 3.558187876508407 代数： 211
# 最优值： 0.88500524 扰动程度： 3.503882898863605 代数： 212
# 最优值： 0.88587487 扰动程度： 3.495960374436121 代数： 213
# 最优值： 0.8859781 扰动程度： 3.483573573189005 代数： 214
# 最优值： 0.8947409 扰动程度： 3.415082620492844 代数： 215
# 最优值： 0.8988847 扰动程度： 3.3338405288450357 代数： 216
# attack
# 最优值： 0.89782214 扰动程度： 3.348679909846409 代数： 217
# 最优值： 0.897346 扰动程度： 3.3729077014929456 代数： 218
# 最优值： 0.89343476 扰动程度： 3.4246269372280094 代数： 219
# 最优值： 0.8915965 扰动程度： 3.5044428076901415 代数： 220
# 最优值： 0.8798312 扰动程度： 3.5896098880734653 代数： 221
# 最优值： 0.8768088 扰动程度： 3.684351248652801 代数： 222
# 最优值： 0.8732014 扰动程度： 3.7061567929892965 代数： 223
# 最优值： 0.8725043 扰动程度： 3.7783751580658405 代数： 224
# 最优值： 0.8691635 扰动程度： 3.769260620715258 代数： 225
# 最优值： 0.8664639 扰动程度： 3.788320174770582 代数： 226
# 最优值： 0.8653776 扰动程度： 3.867363517676439 代数： 227
# 最优值： 0.862401 扰动程度： 3.9143956838545457 代数： 228
# 最优值： 0.86006624 扰动程度： 3.9877763146136216 代数： 229
# 最优值： 0.85197103 扰动程度： 4.0531675702939 代数： 230
# 最优值： 0.8480992 扰动程度： 4.106112649887155 代数： 231
# 最优值： 0.84646827 扰动程度： 4.126179852851643 代数： 232
# 最优值： 0.8455545 扰动程度： 4.138202146046602 代数： 233
# 最优值： 0.8427865 扰动程度： 4.185695524923612 代数： 234
# 最优值： 0.8384355 扰动程度： 4.1869969376654845 代数： 235
# 最优值： 0.83926743 扰动程度： 4.182312942420651 代数： 236
# 最优值： 0.83755636 扰动程度： 4.196242725574591 代数： 237
# 最优值： 0.8355995 扰动程度： 4.191316699574148 代数： 238
# 最优值： 0.83613735 扰动程度： 4.290779628922551 代数： 239
# 最优值： 0.8310382 扰动程度： 4.32918642305421 代数： 240
# 最优值： 0.82417005 扰动程度： 4.318383257198754 代数： 241
# 最优值： 0.823965 扰动程度： 4.32189366341608 代数： 242
# 最优值： 0.82164127 扰动程度： 4.421091950855481 代数： 243
# 最优值： 0.81869096 扰动程度： 4.413448125277472 代数： 244
# 最优值： 0.8130175 扰动程度： 4.397551248782026 代数： 245
# 最优值： 0.8130253 扰动程度： 4.395537625563421 代数： 246
# 最优值： 0.8120418 扰动程度： 4.410875131062701 代数： 247
# 最优值： 0.81010467 扰动程度： 4.452491954779586 代数： 248
# 最优值： 0.8077476 扰动程度： 4.53164727922454 代数： 249
# 最优值： 0.80002517 扰动程度： 4.523290082987209 代数： 250
# 最优值： 0.7963017 扰动程度： 4.607095077465398 代数： 251
# 最优值： 0.7947979 扰动程度： 4.6405595292244675 代数： 252
# 最优值： 0.7934614 扰动程度： 4.718834397804539 代数： 253
# 最优值： 0.78985757 扰动程度： 4.714625650605408 代数： 254
# 最优值： 0.79247963 扰动程度： 4.691439002804804 代数： 255
# 最优值： 0.7849507 扰动程度： 4.729213085554902 代数： 256
# 最优值： 0.7847447 扰动程度： 4.755444178486009 代数： 257
# 最优值： 0.7824124 扰动程度： 4.804289293917781 代数： 258
# 最优值： 0.7780739 扰动程度： 4.8610673043770625 代数： 259
# 最优值： 0.7752141 扰动程度： 4.9349955468674205 代数： 260
# 最优值： 0.77073634 扰动程度： 4.932574182638928 代数： 261
# 最优值： 0.766192 扰动程度： 5.011039820321054 代数： 262
# 最优值： 0.7605406 扰动程度： 5.097136506800322 代数： 263
# 最优值： 0.75537455 扰动程度： 5.073718447327832 代数： 264
# 最优值： 0.7533989 扰动程度： 5.14571424256485 代数： 265
# 最优值： 0.750415 扰动程度： 5.208615463875525 代数： 266
# 最优值： 0.7469331 扰动程度： 5.26369893305345 代数： 267
# 最优值： 0.74286115 扰动程度： 5.33227430364255 代数： 268
# 最优值： 0.7367555 扰动程度： 5.346358192045479 代数： 269
# 最优值： 0.7277345 扰动程度： 5.324451573963707 代数： 270
# 最优值： 0.7297582 扰动程度： 5.297685173659275 代数： 271
# 最优值： 0.7302675 扰动程度： 5.2680367489649775 代数： 272
# 最优值： 0.7254307 扰动程度： 5.33597214541717 代数： 273
# 最优值： 0.7252067 扰动程度： 5.3881378031724205 代数： 274
# 最优值： 0.71709144 扰动程度： 5.47380563788534 代数： 275
# 最优值： 0.71481216 扰动程度： 5.549786112211633 代数： 276
# 最优值： 0.71141785 扰动程度： 5.468414676446739 代数： 277
# 最优值： 0.70832217 扰动程度： 5.566317064850867 代数： 278
# 最优值： 0.701025 扰动程度： 5.6522235034671215 代数： 279
# 最优值： 0.70485127 扰动程度： 5.615047522703794 代数： 280
# 最优值： 0.7014399 扰动程度： 5.707561652537468 代数： 281
# 最优值： 0.6944513 扰动程度： 5.779346431791026 代数： 282
# resume
# 最优值： 0.7035447 扰动程度： 5.539314759397135 代数： 283
# 最优值： 0.7127381 扰动程度： 5.3900173858551454 代数： 284
# 最优值： 0.7221192 扰动程度： 5.273143077136771 代数： 285
# 最优值： 0.7260133 扰动程度： 5.228246991644591 代数： 286
# 最优值： 0.72577846 扰动程度： 5.22025734444024 代数： 287
# 最优值： 0.73527217 扰动程度： 5.172171883601159 代数： 288
# 最优值： 0.7281476 扰动程度： 5.133856603028708 代数： 289
# 最优值： 0.73005235 扰动程度： 5.122345567685161 代数： 290
# 最优值： 0.73593134 扰动程度： 5.119256869245062 代数： 291
# 最优值： 0.74510276 扰动程度： 5.0774321127321205 代数： 292
# 最优值： 0.743166 扰动程度： 5.066658006889898 代数： 293
# 最优值： 0.7491902 扰动程度： 4.990109293901464 代数： 294
# 最优值： 0.7507353 扰动程度： 4.928807598699843 代数： 295
# 最优值： 0.75317466 扰动程度： 4.887832266380478 代数： 296
# 最优值： 0.75093925 扰动程度： 4.8438535435265715 代数： 297
# 最优值： 0.7502704 扰动程度： 4.858946239055756 代数： 298
# 最优值： 0.7502499 扰动程度： 4.854974583828914 代数： 299
# 最优值： 0.75086457 扰动程度： 4.852353459642295 代数： 300
# 最优值： 0.75937647 扰动程度： 4.804827210634323 代数： 301
# 最优值： 0.7631462 扰动程度： 4.770293333607643 代数： 302
# 最优值： 0.7729911 扰动程度： 4.70362669814341 代数： 303
# 最优值： 0.78108007 扰动程度： 4.588476922035136 代数： 304
# 最优值： 0.78782016 扰动程度： 4.516423125660417 代数： 305
# 最优值： 0.78780913 扰动程度： 4.51306858542743 代数： 306
# 最优值： 0.785323 扰动程度： 4.52282723561368 代数： 307
# 最优值： 0.7928373 扰动程度： 4.507796388135879 代数： 308
# 最优值： 0.7950734 扰动程度： 4.380608717782825 代数： 309
# 最优值： 0.79447275 扰动程度： 4.390064516982979 代数： 310
# 最优值： 0.80160385 扰动程度： 4.3553403641397805 代数： 311
# 最优值： 0.8110941 扰动程度： 4.276287365594364 代数： 312
# 最优值： 0.82057446 扰动程度： 4.252115729888638 代数： 313
# 最优值： 0.8182941 扰动程度： 4.185985205973244 代数： 314
# 最优值： 0.8230788 扰动程度： 4.118082700119072 代数： 315
# 最优值： 0.8247253 扰动程度： 4.088116736257343 代数： 316
# 最优值： 0.82800645 扰动程度： 4.032383815902677 代数： 317
# 最优值： 0.8278334 扰动程度： 4.041806644739388 代数： 318
# 最优值： 0.8268798 扰动程度： 3.991502883589068 代数： 319
# 最优值： 0.8356447 扰动程度： 3.9426341878244324 代数： 320
# 最优值： 0.84157014 扰动程度： 3.8757308167960147 代数： 321
# 最优值： 0.8412975 扰动程度： 3.888285924838505 代数： 322
# 最优值： 0.8447024 扰动程度： 3.843531517227304 代数： 323
# 最优值： 0.84745646 扰动程度： 3.8071883151102486 代数： 324
# 最优值： 0.8520289 扰动程度： 3.7966814364009864 代数： 325
# attack
# 最优值： 0.84062064 扰动程度： 3.875155972912121 代数： 326
# 最优值： 0.8370359 扰动程度： 3.936621003412182 代数： 327
# 最优值： 0.8299906 扰动程度： 3.9434535863037423 代数： 328
# 最优值： 0.82836515 扰动程度： 4.013378045648656 代数： 329
# 最优值： 0.8190357 扰动程度： 4.084365210857755 代数： 330
# 最优值： 0.81381875 扰动程度： 4.166465384727701 代数： 331
# 最优值： 0.80757713 扰动程度： 4.257253122853637 代数： 332
# 最优值： 0.8000306 扰动程度： 4.333302031453311 代数： 333
# 最优值： 0.7972653 扰动程度： 4.403764312132529 代数： 334
# 最优值： 0.79487604 扰动程度： 4.479307543329899 代数： 335
# 最优值： 0.7807938 扰动程度： 4.510285375075502 代数： 336
# 最优值： 0.78130656 扰动程度： 4.50664996136208 代数： 337
# 最优值： 0.7797973 扰动程度： 4.5674130611903125 代数： 338
# 最优值： 0.77475804 扰动程度： 4.615534690909605 代数： 339
# 最优值： 0.76851225 扰动程度： 4.713434600854301 代数： 340
# 最优值： 0.76462764 扰动程度： 4.727564411418504 代数： 341
# 最优值： 0.7597326 扰动程度： 4.765977909016174 代数： 342
# 最优值： 0.7554035 扰动程度： 4.859596209656314 代数： 343
# 最优值： 0.7498958 扰动程度： 4.897145362941641 代数： 344
# 最优值： 0.74218994 扰动程度： 4.958606631008312 代数： 345
# 最优值： 0.7439887 扰动程度： 4.935581649143859 代数： 346
# 最优值： 0.7404691 扰动程度： 4.899369625418738 代数： 347
# 最优值： 0.7385362 扰动程度： 4.9369838471422 代数： 348
# 最优值： 0.73365605 扰动程度： 5.033971681992474 代数： 349
# 最优值： 0.72469866 扰动程度： 5.091774923081218 代数： 350
# 最优值： 0.72370565 扰动程度： 5.115205909004162 代数： 351
# 最优值： 0.72469145 扰动程度： 5.1076092880334345 代数： 352
# 最优值： 0.7187481 扰动程度： 5.0795465580068315 代数： 353
# 最优值： 0.7192312 扰动程度： 5.08382736262073 代数： 354
# 最优值： 0.71899265 扰动程度： 5.101285005732333 代数： 355
# 最优值： 0.71670896 扰动程度： 5.139849596698997 代数： 356
# 最优值： 0.71366435 扰动程度： 5.124334766071872 代数： 357
# 最优值： 0.71339434 扰动程度： 5.1993752046854 代数： 358
# 最优值： 0.7046798 扰动程度： 5.258826503378984 代数： 359
# 最优值： 0.6987688 扰动程度： 5.325246858940599 代数： 360
# 最优值： 0.68969417 扰动程度： 5.3242356212418755 代数： 361
# 最优值： 0.69454354 扰动程度： 5.386379332204302 代数： 362
# 最优值： 0.6821593 扰动程度： 5.458355545076167 代数： 363
# 最优值： 0.6801219 扰动程度： 5.50193626938889 代数： 364
# 最优值： 0.6798824 扰动程度： 5.500695675867497 代数： 365
# 最优值： 0.67373013 扰动程度： 5.559692584128248 代数： 366
# 最优值： 0.67206997 扰动程度： 5.52636571934682 代数： 367
# 最优值： 0.6683804 扰动程度： 5.571109270209547 代数： 368
# 最优值： 0.6657438 扰动程度： 5.6258074629131585 代数： 369
# 最优值： 0.6647863 扰动程度： 5.634349028755925 代数： 370
# 最优值： 0.6585053 扰动程度： 5.696096468393107 代数： 371
# 最优值： 0.65422803 扰动程度： 5.742585642439898 代数： 372
# 最优值： 0.6490701 扰动程度： 5.769746035478727 代数： 373
# 最优值： 0.6418135 扰动程度： 5.824815962529167 代数： 374
# 最优值： 0.6441024 扰动程度： 5.807607013453516 代数： 375
# 最优值： 0.63376296 扰动程度： 5.8416333246728716 代数： 376
# 最优值： 0.63193136 扰动程度： 5.871448993723461 代数： 377
# 最优值： 0.6340882 扰动程度： 5.857875050909069 代数： 378
# 最优值： 0.63077706 扰动程度： 5.939987658162281 代数： 379
# 最优值： 0.6273357 扰动程度： 6.00257336175562 代数： 380
# 最优值： 0.6182203 扰动程度： 6.096431762347887 代数： 381
# 最优值： 0.6092387 扰动程度： 6.175756602277977 代数： 382
# 最优值： 0.60488284 扰动程度： 6.179646621964737 代数： 383
# 最优值： 0.60150635 扰动程度： 6.210061535606674 代数： 384
# 最优值： 0.60089266 扰动程度： 6.116569826293118 代数： 385
# 最优值： 0.6028787 扰动程度： 6.100617897758227 代数： 386
# 最优值： 0.6012008 扰动程度： 6.113995946007131 代数： 387
# 最优值： 0.596439 扰动程度： 6.197606973452556 代数： 388
# resume
# 最优值： 0.60174906 扰动程度： 6.089289467809824 代数： 389
# 最优值： 0.60616845 扰动程度： 6.074388160643883 代数： 390
# 最优值： 0.61458266 扰动程度： 6.02976333891545 代数： 391
# 最优值： 0.6176452 扰动程度： 5.94077899380442 代数： 392
# 最优值： 0.62321025 扰动程度： 5.893362689812539 代数： 393
# 最优值： 0.62725663 扰动程度： 5.822565001766563 代数： 394
# 最优值： 0.63695925 扰动程度： 5.776981426701607 代数： 395
# 最优值： 0.64547944 扰动程度： 5.657743746939318 代数： 396
# 最优值： 0.64551765 扰动程度： 5.652207341855823 代数： 397
# 最优值： 0.6518679 扰动程度： 5.6218232191472275 代数： 398
# 最优值： 0.6578563 扰动程度： 5.561715735841313 代数： 399
# 最优值： 0.66317725 扰动程度： 5.522401382262447 代数： 400
# 最优值： 0.6682081 扰动程度： 5.434840047463652 代数： 401
# 最优值： 0.679296 扰动程度： 5.309550590530112 代数： 402
# 最优值： 0.69768363 扰动程度： 5.157651685996947 代数： 403
# 最优值： 0.70440096 扰动程度： 5.133852885936007 代数： 404
# 最优值： 0.706977 扰动程度： 5.074926714912137 代数： 405
# 最优值： 0.71105546 扰动程度： 4.985880974005194 代数： 406
# 最优值： 0.7167127 扰动程度： 4.929270323946488 代数： 407
# 最优值： 0.72178835 扰动程度： 4.930887021253441 代数： 408
# 最优值： 0.72687745 扰动程度： 4.852131050037711 代数： 409
# 最优值： 0.7314843 扰动程度： 4.745444260879541 代数： 410
# 最优值： 0.7401181 扰动程度： 4.730787934839032 代数： 411
# 最优值： 0.74226886 扰动程度： 4.632727154259216 代数： 412
# 最优值： 0.7461544 扰动程度： 4.604833620908409 代数： 413
# 最优值： 0.74645406 扰动程度： 4.585941672514862 代数： 414
# 最优值： 0.74656487 扰动程度： 4.5835203410032435 代数： 415
# 最优值： 0.75272715 扰动程度： 4.572531992277116 代数： 416
# 最优值： 0.7576294 扰动程度： 4.540656573379842 代数： 417
# 最优值： 0.76540834 扰动程度： 4.3833597418476815 代数： 418
# 最优值： 0.7656538 扰动程度： 4.374963643908131 代数： 419
# 最优值： 0.7736786 扰动程度： 4.359314291964973 代数： 420
# 最优值： 0.7775281 扰动程度： 4.32801852262334 代数： 421
# 最优值： 0.78291994 扰动程度： 4.24883319212956 代数： 422
# 最优值： 0.78245157 扰动程度： 4.239620503453878 代数： 423
# 最优值： 0.7832628 扰动程度： 4.23291514140715 代数： 424
# 最优值： 0.78624576 扰动程度： 4.228830343890134 代数： 425
# 最优值： 0.787108 扰动程度： 4.217250215708827 代数： 426
# 最优值： 0.7969813 扰动程度： 4.163805515182586 代数： 427
# attack
# 最优值： 0.78260416 扰动程度： 4.2597035847473705 代数： 428
# 最优值： 0.7666491 扰动程度： 4.335520306988323 代数： 429
# 最优值： 0.7581819 扰动程度： 4.423982444408893 代数： 430
# 最优值： 0.7511307 扰动程度： 4.496857493524824 代数： 431
# 最优值： 0.7475389 扰动程度： 4.594773691015742 代数： 432
# 最优值： 0.73678744 扰动程度： 4.656802024329332 代数： 433
# 最优值： 0.73120546 扰动程度： 4.721246722573857 代数： 434
# 最优值： 0.7215082 扰动程度： 4.746152958273968 代数： 435
# 最优值： 0.72229105 扰动程度： 4.843364448030877 代数： 436
# 最优值： 0.70901746 扰动程度： 4.935929876646779 代数： 437
# 最优值： 0.7033388 扰动程度： 5.010059051919373 代数： 438
# 最优值： 0.7035138 扰动程度： 5.018778352940396 代数： 439
# 最优值： 0.69558614 扰动程度： 5.109278418676459 代数： 440
# 最优值： 0.6782555 扰动程度： 5.121710811138161 代数： 441
# 最优值： 0.67821467 扰动程度： 5.129612013889003 代数： 442
# 最优值： 0.6791624 扰动程度： 5.119466833046412 代数： 443
# 最优值： 0.66942865 扰动程度： 5.216231384086875 代数： 444
# 最优值： 0.6728248 扰动程度： 5.187650156927466 代数： 445
# 最优值： 0.67225283 扰动程度： 5.176334624459373 代数： 446
# 最优值： 0.6698453 扰动程度： 5.214372644002549 代数： 447
# 最优值： 0.657978 扰动程度： 5.337572815707765 代数： 448
# 最优值： 0.65878874 扰动程度： 5.3650134080786325 代数： 449
# 最优值： 0.65419555 扰动程度： 5.389016204241295 代数： 450
# 最优值： 0.6488204 扰动程度： 5.4834685419813844 代数： 451
# 最优值： 0.6451741 扰动程度： 5.503726003004338 代数： 452
# 最优值： 0.63613796 扰动程度： 5.459232799974868 代数： 453
# 最优值： 0.633104 扰动程度： 5.5445050853412985 代数： 454
# 最优值： 0.6330928 扰动程度： 5.5239649468200405 代数： 455
# 最优值： 0.63213384 扰动程度： 5.607795705602042 代数： 456
# 最优值： 0.62475866 扰动程度： 5.652069330889625 代数： 457
# 最优值： 0.62202364 扰动程度： 5.695074500394524 代数： 458
# 最优值： 0.6081681 扰动程度： 5.7820910470966815 代数： 459
# 最优值： 0.6075769 扰动程度： 5.880476172583844 代数： 460
# 最优值： 0.59726554 扰动程度： 5.923299341123818 代数： 461
# 最优值： 0.5931349 扰动程度： 5.964335074174707 代数： 462
# 最优值： 0.59301764 扰动程度： 5.883393269747452 代数： 463
# 最优值： 0.5930649 扰动程度： 5.927855710730493 代数： 464
# 最优值： 0.5845847 扰动程度： 6.0137047587338 代数： 465
# 最优值： 0.5776508 扰动程度： 6.005043515785282 代数： 466
# 最优值： 0.5743853 扰动程度： 6.041635062750348 代数： 467
# 最优值： 0.5725237 扰动程度： 6.1279508037190675 代数： 468
# 最优值： 0.5683816 扰动程度： 6.204289966441619 代数： 469
# 最优值： 0.5563207 扰动程度： 6.25468066844347 代数： 470
# 最优值： 0.5539895 扰动程度： 6.27672856841104 代数： 471
# 最优值： 0.5524298 扰动程度： 6.356663850238789 代数： 472
# 最优值： 0.54747874 扰动程度： 6.330264836738249 代数： 473
# 最优值： 0.54394627 扰动程度： 6.366981164092574 代数： 474
# 最优值： 0.5369438 扰动程度： 6.4276886838969745 代数： 475
# 最优值： 0.529452 扰动程度： 6.519678185706032 代数： 476
# 最优值： 0.52368766 扰动程度： 6.585281684197722 代数： 477
# 最优值： 0.52336377 扰动程度： 6.530491938530884 代数： 478
# 最优值： 0.5190386 扰动程度： 6.617639781190678 代数： 479
# 最优值： 0.5106451 扰动程度： 6.66092005655276 代数： 480
# 最优值： 0.50506186 扰动程度： 6.719280529693975 代数： 481
# 最优值： 0.50119793 扰动程度： 6.773587809151294 代数： 482
# 最优值： 0.49840686 扰动程度： 6.810483712431495 代数： 483
# resume
# 最优值： 0.5034293 扰动程度： 6.617948473818697 代数： 484
# 最优值： 0.51238406 扰动程度： 6.632409079438288 代数： 485
# 最优值： 0.5165107 扰动程度： 6.437231440054399 代数： 486
# 最优值： 0.51609164 扰动程度： 6.456932394629554 代数： 487
# 最优值： 0.52221566 扰动程度： 6.3865664405476235 代数： 488
# 最优值： 0.5311741 扰动程度： 6.369022920668071 代数： 489
# 最优值： 0.5402514 扰动程度： 6.295909021404031 代数： 490
# 最优值： 0.5501159 扰动程度： 6.17435231912291 代数： 491
# 最优值： 0.55710447 扰动程度： 6.1260729591782335 代数： 492
# 最优值： 0.5494954 扰动程度： 6.134079781644394 代数： 493
# 最优值： 0.55817217 扰动程度： 6.136986580642523 代数： 494
# 最优值： 0.56102455 扰动程度： 6.04381491600897 代数： 495
# 最优值： 0.5634161 扰动程度： 6.0415876094123755 代数： 496
# 最优值： 0.5715247 扰动程度： 5.92843418185514 代数： 497
# 最优值： 0.57320756 扰动程度： 5.910049048031905 代数： 498
# 最优值： 0.57422215 扰动程度： 5.899999363446346 代数： 499
# 最优值： 0.5820231 扰动程度： 5.839934937613192 代数： 500
# 最优值： 0.5865075 扰动程度： 5.783125389678669 代数： 501
# 最优值： 0.5952087 扰动程度： 5.721802306234351 代数： 502
# 最优值： 0.60121036 扰动程度： 5.662708117014903 代数： 503
# 最优值： 0.6053648 扰动程度： 5.572580918222586 代数： 504
# 最优值： 0.6140375 扰动程度： 5.567852047643869 代数： 505
# 最优值： 0.62144846 扰动程度： 5.502949362515225 代数： 506
# 最优值： 0.62789863 扰动程度： 5.423037453860073 代数： 507
# 最优值： 0.6326091 扰动程度： 5.363245287455356 代数： 508
# 最优值： 0.6417812 扰动程度： 5.300854790777584 代数： 509
# 最优值： 0.6507561 扰动程度： 5.239874123088019 代数： 510
# 最优值： 0.6514244 扰动程度： 5.18999815619246 代数： 511
# 最优值： 0.6494658 扰动程度： 5.191927903863585 代数： 512
# 最优值： 0.6583705 扰动程度： 5.141044018111753 代数： 513
# 最优值： 0.6603481 扰动程度： 5.087784462162624 代数： 514
# 最优值： 0.6635288 扰动程度： 5.099444050155361 代数： 515
# 最优值： 0.67336094 扰动程度： 5.008322568734575 代数： 516
# 最优值： 0.68213767 扰动程度： 4.990859624611522 代数： 517
# 最优值： 0.68893546 扰动程度： 4.9045278925730695 代数： 518
# 最优值： 0.689611 扰动程度： 4.916889304755238 代数： 519
# 最优值： 0.6979364 扰动程度： 4.845951623943009 代数： 520
# 最优值： 0.70237005 扰动程度： 4.782241868462449 代数： 521
# 最优值： 0.70574063 扰动程度： 4.793506188809856 代数： 522
# 最优值： 0.70658785 扰动程度： 4.747938262978796 代数： 523
# 最优值： 0.71080005 扰动程度： 4.684699153220834 代数： 524
# 最优值： 0.7152052 扰动程度： 4.648453968870472 代数： 525
# 最优值： 0.7191786 扰动程度： 4.621078741008115 代数： 526
# 最优值： 0.7268298 扰动程度： 4.531385202857207 代数： 527
# attack
# 最优值： 0.7209106 扰动程度： 4.63082122410488 代数： 528
# 最优值： 0.7126402 扰动程度： 4.702115590562207 代数： 529
# 最优值： 0.70077485 扰动程度： 4.719184009867022 代数： 530
# 最优值： 0.68457687 扰动程度： 4.842203968559128 代数： 531
# 最优值： 0.683287 扰动程度： 4.927284490145745 代数： 532
# 最优值： 0.67368335 扰动程度： 4.9665934067124695 代数： 533
# 最优值： 0.6609882 扰动程度： 5.0283527698964585 代数： 534
# 最优值： 0.6617045 扰动程度： 5.063410031548412 代数： 535
# 最优值： 0.66453296 扰动程度： 5.0480084805900045 代数： 536
# 最优值： 0.6556143 扰动程度： 5.067293040361854 代数： 537
# 最优值： 0.649643 扰动程度： 5.164578658834602 代数： 538
# 最优值： 0.63605255 扰动程度： 5.277299933007383 代数： 539
# 最优值： 0.6198656 扰动程度： 5.4221804014908 代数： 540
# 最优值： 0.6287352 扰动程度： 5.326848703894267 代数： 541
# 最优值： 0.6266785 扰动程度： 5.342711884834417 代数： 542
# 最优值： 0.62798876 扰动程度： 5.306979976677943 代数： 543
# 最优值： 0.620078 扰动程度： 5.406570159286035 代数： 544
# 最优值： 0.61899316 扰动程度： 5.4560735584429505 代数： 545
# 最优值： 0.61073947 扰动程度： 5.510766946928855 代数： 546
# 最优值： 0.609603 扰动程度： 5.528425847569002 代数： 547
# 最优值： 0.5990927 扰动程度： 5.563128421310847 代数： 548
# 最优值： 0.5995785 扰动程度： 5.611118476741698 代数： 549
# 最优值： 0.59054315 扰动程度： 5.64394390490062 代数： 550
# 最优值： 0.58469266 扰动程度： 5.705055987455422 代数： 551
# 最优值： 0.5722557 扰动程度： 5.796168366919154 代数： 552
# 最优值： 0.5705487 扰动程度： 5.8146171560121465 代数： 553
# 最优值： 0.56876004 扰动程度： 5.840438900674882 代数： 554
# 最优值： 0.56189007 扰动程度： 5.907573047339448 代数： 555
# 最优值： 0.55440086 扰动程度： 5.9925837166594595 代数： 556
# 最优值： 0.551958 扰动程度： 6.0215180673875865 代数： 557
# 最优值： 0.5474236 扰动程度： 6.062735253043102 代数： 558
# 最优值： 0.53132427 扰动程度： 6.073104539912834 代数： 559
# 最优值： 0.5283509 扰动程度： 6.107433626052347 代数： 560
# 最优值： 0.5281767 扰动程度： 6.111732773920076 代数： 561
# 最优值： 0.52308947 扰动程度： 6.188269503851184 代数： 562
# 最优值： 0.5148885 扰动程度： 6.286139304227104 代数： 563
# 最优值： 0.508778 扰动程度： 6.374486716611724 代数： 564
# 最优值： 0.5013748 扰动程度： 6.459118270259473 代数： 565
# 最优值： 0.495065 扰动程度： 6.459363452058225 代数： 566
# 最优值： 0.49611768 扰动程度： 6.527791811184859 代数： 567
# 最优值： 0.48158723 扰动程度： 6.579278237697093 代数： 568
# 最优值： 0.4777615 扰动程度： 6.618855842962775 代数： 569
# 最优值： 0.4765264 扰动程度： 6.639885268393455 代数： 570
# 最优值： 0.4708844 扰动程度： 6.644226237601241 代数： 571
# 最优值： 0.4710275 扰动程度： 6.638087233662745 代数： 572
# 最优值： 0.46716017 扰动程度： 6.737843449379037 代数： 573
# 最优值： 0.46424732 扰动程度： 6.815619216929824 代数： 574
# 最优值： 0.45435917 扰动程度： 6.836976817770825 代数： 575
# 最优值： 0.43948534 扰动程度： 6.892053760265288 代数： 576
# 最优值： 0.43261772 扰动程度： 6.959961802861611 代数： 577
# 最优值： 0.4336201 扰动程度： 6.946887253880477 代数： 578
# 最优值： 0.42892343 扰动程度： 7.025445645002632 代数： 579
# 最优值： 0.42238313 扰动程度： 7.074257607051693 代数： 580
# 最优值： 0.4225717 扰动程度： 7.04136867048923 代数： 581
# 最优值： 0.42018276 扰动程度： 7.069442747913973 代数： 582
# 最优值： 0.4103032 扰动程度： 7.159602443586167 代数： 583
# 最优值： 0.4074393 扰动程度： 7.244824871250986 代数： 584
# 最优值： 0.405636 扰动程度： 7.220634850626925 代数： 585
# 最优值： 0.39793074 扰动程度： 7.285588898263564 代数： 586
# resume
# 最优值： 0.40136412 扰动程度： 7.219833423806849 代数： 587
# 最优值： 0.40806243 扰动程度： 7.20099508164642 代数： 588
# 最优值： 0.41126382 扰动程度： 7.091024862128024 代数： 589
# 最优值： 0.4209122 扰动程度： 6.994514165485291 代数： 590
# 最优值： 0.42244458 扰动程度： 6.978731867159264 代数： 591
# 最优值： 0.43241063 扰动程度： 6.933291956120668 代数： 592
# 最优值： 0.43821126 扰动程度： 6.838621532763192 代数： 593
# 最优值： 0.4402871 扰动程度： 6.816287675887614 代数： 594
# 最优值： 0.44439152 扰动程度： 6.771943611291988 代数： 595
# 最优值： 0.45430553 扰动程度： 6.683577830243594 代数： 596
# 最优值： 0.45487776 扰动程度： 6.677675340237108 代数： 597
# 最优值： 0.46283257 扰动程度： 6.541630596415928 代数： 598
# 最优值： 0.46283257 扰动程度： 6.541630596415928 代数： 599
# 最优值： 0.47123125 扰动程度： 6.520524854626096 代数： 600
# 最优值： 0.47835895 扰动程度： 6.410409637052401 代数： 601
# 最优值： 0.48207498 扰动程度： 6.306826211437042 代数： 602
# 最优值： 0.4912872 扰动程度： 6.242131380322583 代数： 603
# 最优值： 0.5008893 扰动程度： 6.238078438398773 代数： 604
# 最优值： 0.5089823 扰动程度： 6.1794871012640495 代数： 605
# 最优值： 0.51312006 扰动程度： 6.160454397500773 代数： 606
# 最优值： 0.51809794 扰动程度： 6.094837817491332 代数： 607
# 最优值： 0.5271635 扰动程度： 5.9963451887703405 代数： 608
# 最优值： 0.52833414 扰动程度： 6.0035434597609845 代数： 609
# 最优值： 0.5338219 扰动程度： 5.941151224735004 代数： 610
# 最优值： 0.5326085 扰动程度： 5.939464482181404 代数： 611
# 最优值： 0.5335992 扰动程度： 5.908740809536686 代数： 612
# 最优值： 0.5435298 扰动程度： 5.850995988606051 代数： 613
# 最优值： 0.5474174 扰动程度： 5.786849503007942 代数： 614
# 最优值： 0.54940885 扰动程度： 5.774342442949735 代数： 615
# 最优值： 0.5548815 扰动程度： 5.72207836426765 代数： 616
# 最优值： 0.56166524 扰动程度： 5.681407961696439 代数： 617
# 最优值： 0.57092196 扰动程度： 5.5661532230735 代数： 618
# 最优值： 0.57726556 扰动程度： 5.574208494643524 代数： 619
# 最优值： 0.58186615 扰动程度： 5.526962231102869 代数： 620
# 最优值： 0.58358014 扰动程度： 5.520541172534013 代数： 621
# 最优值： 0.58530366 扰动程度： 5.496081179271563 代数： 622
# 最优值： 0.5823354 扰动程度： 5.487972307295219 代数： 623
# 最优值： 0.5838459 扰动程度： 5.4716394709209935 代数： 624
# 最优值： 0.5902791 扰动程度： 5.440791110241156 代数： 625
# 最优值： 0.5935815 扰动程度： 5.391616740247299 代数： 626
# 最优值： 0.6012121 扰动程度： 5.330381619491401 代数： 627
# 最优值： 0.60797286 扰动程度： 5.302843203732568 代数： 628
# 最优值： 0.6147991 扰动程度： 5.264270270751764 代数： 629
# 最优值： 0.6238734 扰动程度： 5.227131762788201 代数： 630
# 最优值： 0.6239321 扰动程度： 5.204480751523994 代数： 631
# 最优值： 0.62651587 扰动程度： 5.173546194502774 代数： 632
# 最优值： 0.6327688 扰动程度： 5.09074025230797 代数： 633
# 最优值： 0.64017063 扰动程度： 5.037650063570181 代数： 634
# 最优值： 0.6405719 扰动程度： 5.04356377340899 代数： 635
# 最优值： 0.6346938 扰动程度： 5.07062545612685 代数： 636
# 最优值： 0.6431042 扰动程度： 5.026691919654558 代数： 637
# 最优值： 0.6499411 扰动程度： 4.961323318910664 代数： 638
# attack
# 最优值： 0.65215564 扰动程度： 4.955110506017561 代数： 639
# 最优值： 0.6404029 扰动程度： 5.054692383648074 代数： 640
# 最优值： 0.623449 扰动程度： 5.147352133613919 代数： 641
# 最优值： 0.607776 扰动程度： 5.240081274195758 代数： 642
# 最优值： 0.5998365 扰动程度： 5.312848349100059 代数： 643
# 最优值： 0.58352315 扰动程度： 5.391760853537146 代数： 644
# 最优值： 0.58512723 扰动程度： 5.383191916809095 代数： 645
# 最优值： 0.57887816 扰动程度： 5.4345617181596335 代数： 646
# 最优值： 0.575584 扰动程度： 5.4933166373819855 代数： 647
# 最优值： 0.5736478 扰动程度： 5.5371426517717195 代数： 648
# 最优值： 0.56593573 扰动程度： 5.618292314287484 代数： 649
# 最优值： 0.5579318 扰动程度： 5.664229849656521 代数： 650
# 最优值： 0.5557199 扰动程度： 5.652757505534739 代数： 651
# 最优值： 0.54098064 扰动程度： 5.729282789089915 代数： 652
# 最优值： 0.54415184 扰动程度： 5.7021335531723505 代数： 653
# 最优值： 0.53624797 扰动程度： 5.79106837837262 代数： 654
# 最优值： 0.53063637 扰动程度： 5.8472093959559786 代数： 655
# 最优值： 0.5221575 扰动程度： 5.920490362287856 代数： 656
# 最优值： 0.51348203 扰动程度： 5.981363883528507 代数： 657
# 最优值： 0.5152788 扰动程度： 5.960102560371362 代数： 658
# 最优值： 0.51367944 扰动程度： 5.993068047947199 代数： 659
# 最优值： 0.5112617 扰动程度： 6.058517657535356 代数： 660
# 最优值： 0.50146747 扰动程度： 6.082703372977694 代数： 661
# 最优值： 0.49715686 扰动程度： 6.1048714067975025 代数： 662
# 最优值： 0.49213272 扰动程度： 6.196261276233279 代数： 663
# 最优值： 0.48776865 扰动程度： 6.206082564490193 代数： 664
# 最优值： 0.47398674 扰动程度： 6.305022907925508 代数： 665
# 最优值： 0.4809588 扰动程度： 6.261855373961283 代数： 666
# 最优值： 0.4753742 扰动程度： 6.318775795806222 代数： 667
# 最优值： 0.4660522 扰动程度： 6.3767277814456955 代数： 668
# 最优值： 0.45825475 扰动程度： 6.442433675522436 代数： 669
# 最优值： 0.45672053 扰动程度： 6.45265877488096 代数： 670
# 最优值： 0.4524408 扰动程度： 6.4899687146558875 代数： 671
# 最优值： 0.44204804 扰动程度： 6.563265750244598 代数： 672
# 最优值： 0.43878824 扰动程度： 6.61361360417336 代数： 673
# 最优值： 0.43098602 扰动程度： 6.682086332601785 代数： 674
# 最优值： 0.42867813 扰动程度： 6.741218265969497 代数： 675
# 最优值： 0.42643237 扰动程度： 6.806888789409531 代数： 676
# 最优值： 0.41806573 扰动程度： 6.885251311308208 代数： 677
# 最优值： 0.41027427 扰动程度： 6.979469901373988 代数： 678
# 最优值： 0.4052384 扰动程度： 7.01975275849512 代数： 679
# 最优值： 0.40471947 扰动程度： 7.032764027105763 代数： 680
# 最优值： 0.3930934 扰动程度： 7.090273010126198 代数： 681
# 最优值： 0.3888076 扰动程度： 7.185317958986415 代数： 682
# 最优值： 0.3825053 扰动程度： 7.218056854776105 代数： 683
# 最优值： 0.37237197 扰动程度： 7.300103558351237 代数： 684
# 最优值： 0.3734446 扰动程度： 7.294971499724133 代数： 685
# 最优值： 0.3686029 扰动程度： 7.2630301380404845 代数： 686
# 最优值： 0.36153403 扰动程度： 7.3506826707501265 代数： 687
# 最优值： 0.36068916 扰动程度： 7.3609845122328235 代数： 688
# 最优值： 0.35252583 扰动程度： 7.425581721650837 代数： 689
# 最优值： 0.35299736 扰动程度： 7.419486479185968 代数： 690
# 最优值： 0.34903184 扰动程度： 7.514489902165891 代数： 691
# 最优值： 0.34839904 扰动程度： 7.564336973512522 代数： 692
# 最优值： 0.33527 扰动程度： 7.574165169773151 代数： 693
# 最优值： 0.33643848 扰动程度： 7.644024390999093 代数： 694
# 最优值： 0.32617876 扰动程度： 7.738274269946735 代数： 695
# 最优值： 0.32154453 扰动程度： 7.789486081961076 代数： 696
# 最优值： 0.31447294 扰动程度： 7.881891638839538 代数： 697
# 最优值： 0.31122836 扰动程度： 7.963963083091472 代数： 698
# 最优值： 0.30156955 扰动程度： 8.003839890478591 代数： 699
# 最优值： 0.30148748 扰动程度： 8.005275638049874 代数： 700
# 最优值： 0.2958377 扰动程度： 8.092764338231843 代数： 701
# resume
# 最优值： 0.30568263 扰动程度： 7.957067906094549 代数： 702
# 最优值： 0.31504112 扰动程度： 7.871676757200038 代数： 703
# 最优值： 0.32449302 扰动程度： 7.792269782111301 代数： 704
# 最优值： 0.33313143 扰动程度： 7.58117775608602 代数： 705
# 最优值： 0.33982918 扰动程度： 7.491350619689353 代数： 706
# 最优值： 0.34830034 扰动程度： 7.419082748628084 代数： 707
# 最优值： 0.35395622 扰动程度： 7.350023796750473 代数： 708
# 最优值： 0.3639268 扰动程度： 7.269429188823103 代数： 709
# 最优值： 0.373207 扰动程度： 7.189717531531937 代数： 710
# 最优值： 0.37445605 扰动程度： 7.068318656360524 代数： 711
# 最优值： 0.37297255 扰动程度： 7.089069957359888 代数： 712
# 最优值： 0.37069952 扰动程度： 7.106892351175737 代数： 713
# 最优值： 0.37722486 扰动程度： 7.072600129687779 代数： 714
# 最优值： 0.37833825 扰动程度： 7.052012341661204 代数： 715
# 最优值： 0.38012627 扰动程度： 7.03504685446032 代数： 716
# 最优值： 0.39001065 扰动程度： 6.9593945562595305 代数： 717
# 最优值： 0.39129674 扰动程度： 6.948768263207249 代数： 718
# 最优值： 0.40030992 扰动程度： 6.928932598036917 代数： 719
# 最优值： 0.4079333 扰动程度： 6.794532422460268 代数： 720
# 最优值： 0.41667506 扰动程度： 6.816397342267574 代数： 721
# 最优值： 0.4185694 扰动程度： 6.66941469851436 代数： 722
# 最优值： 0.4138416 扰动程度： 6.643057248597748 代数： 723
# 最优值： 0.41578874 扰动程度： 6.627058836985359 代数： 724
# 最优值： 0.41995874 扰动程度： 6.588121409936995 代数： 725
# 最优值： 0.42479655 扰动程度： 6.565471222097368 代数： 726
# 最优值： 0.4322749 扰动程度： 6.539984360358354 代数： 727
# 最优值： 0.44102243 扰动程度： 6.460551337287705 代数： 728
# 最优值： 0.44030154 扰动程度： 6.45786548530357 代数： 729
# 最优值： 0.44584924 扰动程度： 6.3922503970850695 代数： 730
# 最优值： 0.44993207 扰动程度： 6.353359398280399 代数： 731
# 最优值： 0.4499397 扰动程度： 6.356729402451297 代数： 732
# 最优值： 0.44894388 扰动程度： 6.357896727441494 代数： 733
# 最优值： 0.4547413 扰动程度： 6.336428215324508 代数： 734
# 最优值： 0.46237502 扰动程度： 6.306679909348662 代数： 735
# 最优值： 0.4649176 扰动程度： 6.252329837670879 代数： 736
# 最优值： 0.46370706 扰动程度： 6.229201616710903 代数： 737
# 最优值： 0.4725025 扰动程度： 6.136778694069816 代数： 738
# 最优值： 0.47310972 扰动程度： 6.12912641029697 代数： 739
# 最优值： 0.4826419 扰动程度： 6.08159184956981 代数： 740
# 最优值： 0.49001673 扰动程度： 6.046638829253261 代数： 741
# 最优值： 0.49248955 扰动程度： 6.00332063488816 代数： 742
# 最优值： 0.49787834 扰动程度： 5.976369011498337 代数： 743
# 最优值： 0.50563204 扰动程度： 5.975915788792959 代数： 744
# 最优值： 0.51137805 扰动程度： 5.91865477840824 代数： 745
# 最优值： 0.51359767 扰动程度： 5.8193306628865935 代数： 746
# 最优值： 0.51433456 扰动程度： 5.8184291019995005 代数： 747
# 最优值： 0.5230876 扰动程度： 5.8032850672682805 代数： 748
# 最优值： 0.52420866 扰动程度： 5.766881866845673 代数： 749
# 最优值： 0.5306198 扰动程度： 5.718081407149812 代数： 750
# 最优值： 0.5369052 扰动程度： 5.644251416767327 代数： 751
# 最优值： 0.54134595 扰动程度： 5.611564685674221 代数： 752
# 最优值： 0.5389073 扰动程度： 5.635635650795471 代数： 753
# 最优值： 0.54536986 扰动程度： 5.613907866516522 代数： 754
# 最优值： 0.550909 扰动程度： 5.555040288564818 代数： 755
# 最优值： 0.55306697 扰动程度： 5.5459831862453965 代数： 756
# 最优值： 0.5534821 扰动程度： 5.544799120073704 代数： 757
# 最优值： 0.5591896 扰动程度： 5.496098400684155 代数： 758
# 最优值： 0.56163263 扰动程度： 5.4718709004129416 代数： 759
# 最优值： 0.56779987 扰动程度： 5.452631746794933 代数： 760
# 最优值： 0.577183 扰动程度： 5.4077585701752895 代数： 761
# 最优值： 0.5848596 扰动程度： 5.3549885326621895 代数： 762
# attack
# 最优值： 0.57770544 扰动程度： 5.41034676311982 代数： 763
# 最优值： 0.5490476 扰动程度： 5.491626526605593 代数： 764
# 最优值： 0.5462918 扰动程度： 5.578251802233719 代数： 765
# 最优值： 0.54017836 扰动程度： 5.5877953824823985 代数： 766
# 最优值： 0.5227021 扰动程度： 5.67838231483461 代数： 767
# 最优值： 0.52125895 扰动程度： 5.691183168133966 代数： 768
# 最优值： 0.5213192 扰动程度： 5.732958046914446 代数： 769
# 最优值： 0.51701957 扰动程度： 5.812743224246926 代数： 770
# 最优值： 0.5104783 扰动程度： 5.8319277855398255 代数： 771
# 最优值： 0.50966626 扰动程度： 5.872202825300325 代数： 772
# 最优值： 0.499247 扰动程度： 5.972093507391014 代数： 773
# 最优值： 0.4879045 扰动程度： 6.031506740428204 代数： 774
# 最优值： 0.47882894 扰动程度： 6.127260567162498 代数： 775
# 最优值： 0.47324467 扰动程度： 6.154209868768573 代数： 776
# 最优值： 0.47232276 扰动程度： 6.17037515631722 代数： 777
# 最优值： 0.46017846 扰动程度： 6.250528783393192 代数： 778
# 最优值： 0.4585784 扰动程度： 6.265008235451245 代数： 779
# 最优值： 0.45458105 扰动程度： 6.288341401208929 代数： 780
# 最优值： 0.45020184 扰动程度： 6.367667532594845 代数： 781
# 最优值： 0.4382252 扰动程度： 6.3914165611960305 代数： 782
# 最优值： 0.43013495 扰动程度： 6.4719333724357915 代数： 783
# 最优值： 0.43454662 扰动程度： 6.432296389905873 代数： 784
# 最优值： 0.4292312 扰动程度： 6.487974208787625 代数： 785
# 最优值： 0.43191966 扰动程度： 6.575679149279717 代数： 786
# 最优值： 0.4117792 扰动程度： 6.675140311315069 代数： 787
# 最优值： 0.40216097 扰动程度： 6.7728076517567 代数： 788
# 最优值： 0.39995247 扰动程度： 6.792312194759756 代数： 789
# 最优值： 0.3874619 扰动程度： 6.865435924315501 代数： 790
# 最优值： 0.38666496 扰动程度： 6.867935636376926 代数： 791
# 最优值： 0.38359877 扰动程度： 6.866076741100854 代数： 792
# 最优值： 0.38371214 扰动程度： 6.923490926291969 代数： 793
# 最优值： 0.3822699 扰动程度： 6.935216421829977 代数： 794
# 最优值： 0.3704486 扰动程度： 6.971930927717598 代数： 795
# 最优值： 0.36929375 扰动程度： 7.030310725551318 代数： 796
# 最优值： 0.36678728 扰动程度： 7.028067765405221 代数： 797
# 最优值： 0.36138207 扰动程度： 7.0372851429588685 代数： 798
# 最优值： 0.35158756 扰动程度： 7.145633315185409 代数： 799
# 最优值： 0.34903806 扰动程度： 7.20157215908893 代数： 800
# 最优值： 0.33608967 扰动程度： 7.292815323591626 代数： 801
# 最优值： 0.3324471 扰动程度： 7.298655728353159 代数： 802
# 最优值： 0.33091664 扰动程度： 7.304779622958586 代数： 803
# 最优值： 0.32433704 扰动程度： 7.403497552401599 代数： 804
# 最优值： 0.32418162 扰动程度： 7.4926746518319565 代数： 805
# 最优值： 0.31664327 扰动程度： 7.562607522163824 代数： 806
# 最优值： 0.3042978 扰动程度： 7.584679333713665 代数： 807
# 最优值： 0.30041522 扰动程度： 7.625606192999598 代数： 808
# 最优值： 0.29645142 扰动程度： 7.6639702319328835 代数： 809
# 最优值： 0.29259428 扰动程度： 7.743027739641057 代数： 810
# 最优值： 0.2905823 扰动程度： 7.80874427454757 代数： 811
# 最优值： 0.27968767 扰动程度： 7.839947160745509 代数： 812
# 最优值： 0.27646613 扰动程度： 7.895848175299203 代数： 813
# 最优值： 0.27367306 扰动程度： 7.959918481932803 代数： 814
# 最优值： 0.25833842 扰动程度： 8.049878779936007 代数： 815
# 最优值： 0.26058084 扰动程度： 8.041842770092178 代数： 816
# 最优值： 0.25711644 扰动程度： 8.060034532963682 代数： 817
# 最优值： 0.2576472 扰动程度： 8.110170441623518 代数： 818
# 最优值： 0.2541418 扰动程度： 8.198545353191863 代数： 819
# 最优值： 0.24832006 扰动程度： 8.266329078498154 代数： 820
# 最优值： 0.24703808 扰动程度： 8.323604425402559 代数： 821
# 最优值： 0.24301484 扰动程度： 8.345053997901164 代数： 822
# 最优值： 0.23310551 扰动程度： 8.445019154015725 代数： 823
# 最优值： 0.22783041 扰动程度： 8.524582154693338 代数： 824
# 最优值： 0.22479612 扰动程度： 8.577658343515525 代数： 825
# 最优值： 0.2255234 扰动程度： 8.567668251434045 代数： 826
# 最优值： 0.22191143 扰动程度： 8.63286215592945 代数： 827
# 最优值： 0.22130314 扰动程度： 8.64186822591932 代数： 828
# 最优值： 0.21768378 扰动程度： 8.699639331409815 代数： 829
# 最优值： 0.21028799 扰动程度： 8.797548771679446 代数： 830
# 最优值： 0.2091541 扰动程度： 8.773686234084712 代数： 831
# 最优值： 0.20770437 扰动程度： 8.830352917211313 代数： 832
# 最优值： 0.20081446 扰动程度： 8.913363874542531 代数： 833
# 最优值： 0.19312221 扰动程度： 9.044504456665454 代数： 834
# resume
# 最优值： 0.2031047 扰动程度： 8.896132438777679 代数： 835
# 最优值： 0.21108511 扰动程度： 8.792698241910038 代数： 836
# 最优值： 0.21995026 扰动程度： 8.579726577975293 代数： 837
# 最优值： 0.22891514 扰动程度： 8.471616456931327 代数： 838
# 最优值： 0.23549277 扰动程度： 8.418925334905216 代数： 839
# 最优值： 0.23984249 扰动程度： 8.306206468076963 代数： 840
# 最优值： 0.241065 扰动程度： 8.281275734483867 代数： 841
# 最优值： 0.24749038 扰动程度： 8.272242610032228 代数： 842
# 最优值： 0.2510382 扰动程度： 8.201748592809416 代数： 843
# 最优值： 0.25567123 扰动程度： 8.158301159110938 代数： 844
# 最优值： 0.26270154 扰动程度： 8.088747812277747 代数： 845
# 最优值： 0.26571223 扰动程度： 7.985905992007177 代数： 846
# 最优值： 0.27556792 扰动程度： 7.863451871477775 代数： 847
# 最优值： 0.28136188 扰动程度： 7.7803385388882305 代数： 848
# 最优值： 0.29100063 扰动程度： 7.708266055719565 代数： 849
# 最优值： 0.28623998 扰动程度： 7.643209090261744 代数： 850
# 最优值： 0.28600547 扰动程度： 7.647962739468548 代数： 851
# 最优值： 0.2934036 扰动程度： 7.607631373257491 代数： 852
# 最优值： 0.30085272 扰动程度： 7.590580547711455 代数： 853
# 最优值： 0.30873007 扰动程度： 7.39169972982535 代数： 854
# 最优值： 0.31383172 扰动程度： 7.348292587012173 代数： 855
# 最优值： 0.31802437 扰动程度： 7.315848544161108 代数： 856
# 最优值： 0.32560995 扰动程度： 7.238986463631794 代数： 857
# 最优值： 0.32524627 扰动程度： 7.24356904126914 代数： 858
# 最优值： 0.33064836 扰动程度： 7.183575938068916 代数： 859
# 最优值： 0.33969876 扰动程度： 7.1706863263701655 代数： 860
# 最优值： 0.3405548 扰动程度： 7.103049851473309 代数： 861
# 最优值： 0.34709755 扰动程度： 7.069540766536072 代数： 862
# 最优值： 0.3480883 扰动程度： 7.066111495298481 代数： 863
# 最优值： 0.3516457 扰动程度： 7.021498642926797 代数： 864
# 最优值： 0.3583703 扰动程度： 6.964372778646815 代数： 865
# 最优值： 0.36299852 扰动程度： 6.953291348214493 代数： 866
# 最优值： 0.37009484 扰动程度： 6.80733484424815 代数： 867
# 最优值： 0.3773214 扰动程度： 6.7593679556033015 代数： 868
# 最优值： 0.3832867 扰动程度： 6.724409338996493 代数： 869
# 最优值： 0.39129576 扰动程度： 6.658076317840332 代数： 870
# 最优值： 0.3915961 扰动程度： 6.660802601696162 代数： 871
# 最优值： 0.39624798 扰动程度： 6.565961387805817 代数： 872
# 最优值： 0.39747754 扰动程度： 6.558516745882414 代数： 873
# 最优值： 0.40864325 扰动程度： 6.469954832201003 代数： 874
# 最优值： 0.40771273 扰动程度： 6.500242347295059 代数： 875
# 最优值： 0.41761345 扰动程度： 6.452331826486412 代数： 876
# 最优值： 0.42113715 扰动程度： 6.382940374782 代数： 877
# 最优值： 0.42230588 扰动程度： 6.350727699289602 代数： 878
# 最优值： 0.4321615 扰动程度： 6.331920532735815 代数： 879
# 最优值： 0.4379431 扰动程度： 6.2507175321927075 代数： 880
# 最优值： 0.4404036 扰动程度： 6.238792578647693 代数： 881
# 最优值： 0.44926265 扰动程度： 6.202544029679622 代数： 882
# 最优值： 0.45490095 扰动程度： 6.164262897234346 代数： 883
# 最优值： 0.46214947 扰动程度： 6.134641227397049 代数： 884
# 最优值： 0.46468633 扰动程度： 6.0826196552296 代数： 885
# 最优值： 0.4641311 扰动程度： 6.052013883509511 代数： 886
# 最优值： 0.4703543 扰动程度： 6.022488416978704 代数： 887
# 最优值： 0.46779314 扰动程度： 6.007637220083477 代数： 888
# 最优值： 0.47279373 扰动程度： 5.959911884982525 代数： 889
# 最优值： 0.4756116 扰动程度： 5.959020731880983 代数： 890
# 最优值： 0.47939306 扰动程度： 5.940409869209316 代数： 891
# 最优值： 0.48866937 扰动程度： 5.841290056322555 代数： 892
# 最优值： 0.49538022 扰动程度： 5.887355985629166 代数： 893
# 最优值： 0.49942142 扰动程度： 5.795171101694919 代数： 894
# attack
# 最优值： 0.48436192 扰动程度： 5.886991846053868 代数： 895
# 最优值： 0.46885696 扰动程度： 5.984948518038599 代数： 896
# 最优值： 0.4604322 扰动程度： 6.063843629175107 代数： 897
# 最优值： 0.4463167 扰动程度： 6.142957938242477 代数： 898
# 最优值： 0.43880403 扰动程度： 6.232341601449038 代数： 899
# 最优值： 0.43332416 扰动程度： 6.264768258160438 代数： 900
# 最优值： 0.4221239 扰动程度： 6.31532370617628 代数： 901
# 最优值： 0.41598046 扰动程度： 6.37754398652968 代数： 902
# 最优值： 0.4060611 扰动程度： 6.459421693843399 代数： 903
# 最优值： 0.40852925 扰动程度： 6.443044115019535 代数： 904
# 最优值： 0.40705088 扰动程度： 6.522176408532804 代数： 905
# 最优值： 0.3977808 扰动程度： 6.620610325948334 代数： 906
# 最优值： 0.38598228 扰动程度： 6.6518498502205095 代数： 907
# 最优值： 0.38013455 扰动程度： 6.621959879961025 代数： 908
# 最优值： 0.37927598 扰动程度： 6.632461616107918 代数： 909
# 最优值： 0.37935072 扰动程度： 6.7227209478424665 代数： 910
# 最优值： 0.3714832 扰动程度： 6.763951312931073 代数： 911
# 最优值： 0.36431548 扰动程度： 6.772376998576567 代数： 912
# 最优值： 0.36517054 扰动程度： 6.769229173079869 代数： 913
# 最优值： 0.35656556 扰动程度： 6.855975447216465 代数： 914
# 最优值： 0.358826 扰动程度： 6.838671973298314 代数： 915
# 最优值： 0.34946278 扰动程度： 6.921784568211026 代数： 916
# 最优值： 0.339797 扰动程度： 7.012490866827215 代数： 917
# 最优值： 0.33583942 扰动程度： 7.053247262717863 代数： 918
# 最优值： 0.33394155 扰动程度： 7.117789111684868 代数： 919
# 最优值： 0.32925048 扰动程度： 7.195657962858408 代数： 920
# 最优值： 0.32154468 扰动程度： 7.209632891188315 代数： 921
# 最优值： 0.31914696 扰动程度： 7.2308607672877345 代数： 922
# 最优值： 0.31393474 扰动程度： 7.323422243684104 代数： 923
# 最优值： 0.3082582 扰动程度： 7.378623290628991 代数： 924
# 最优值： 0.3052857 扰动程度： 7.4425534011107235 代数： 925
# 最优值： 0.29984802 扰动程度： 7.423467472171547 代数： 926
# 最优值： 0.28999156 扰动程度： 7.5074552702030415 代数： 927
# 最优值： 0.28898904 扰动程度： 7.5215050521783935 代数： 928
# 最优值： 0.2867512 扰动程度： 7.579409874369106 代数： 929
# 最优值： 0.2813412 扰动程度： 7.574721870806489 代数： 930
# 最优值： 0.2799023 扰动程度： 7.587985162997932 代数： 931
# 最优值： 0.27910596 扰动程度： 7.608610258003985 代数： 932
# 最优值： 0.2734916 扰动程度： 7.670817815550146 代数： 933
# 最优值： 0.26907364 扰动程度： 7.708875356954568 代数： 934
# 最优值： 0.26772755 扰动程度： 7.761841595287436 代数： 935
# 最优值： 0.26550072 扰动程度： 7.83351598451629 代数： 936
# 最优值： 0.2565325 扰动程度： 7.923028164749604 代数： 937
# 最优值： 0.25554284 扰动程度： 7.937641079363149 代数： 938
# 最优值： 0.25128186 扰动程度： 7.957220260954908 代数： 939
# 最优值： 0.24348827 扰动程度： 8.037275677269 代数： 940
# 最优值： 0.23735696 扰动程度： 8.118532557712184 代数： 941
# 最优值： 0.23727018 扰动程度： 8.15754791576892 代数： 942
# 最优值： 0.23297592 扰动程度： 8.21533510610724 代数： 943
# 最优值： 0.2265713 扰动程度： 8.23055898254864 代数： 944
# 最优值： 0.22304252 扰动程度： 8.283153113839605 代数： 945
# 最优值： 0.22282825 扰动程度： 8.35042683434058 代数： 946
# 最优值： 0.21774285 扰动程度： 8.388155331078126 代数： 947
# 最优值： 0.21730228 扰动程度： 8.400574619057053 代数： 948
# 最优值： 0.21444318 扰动程度： 8.423240330573831 代数： 949
# 最优值： 0.21357325 扰动程度： 8.459278437198613 代数： 950
# 最优值： 0.20860365 扰动程度： 8.479692981501664 代数： 951
# 最优值： 0.20500384 扰动程度： 8.551303816926385 代数： 952
# 最优值： 0.20410304 扰动程度： 8.600789551871383 代数： 953
# 最优值： 0.20088407 扰动程度： 8.662522950688254 代数： 954
# 最优值： 0.20006788 扰动程度： 8.669947770199634 代数： 955
# 最优值： 0.19641341 扰动程度： 8.695195626877279 代数： 956
# 最优值： 0.19387288 扰动程度： 8.741079666220372 代数： 957
# 最优值： 0.18884493 扰动程度： 8.807401411302875 代数： 958
# 最优值： 0.18537103 扰动程度： 8.876259660146244 代数： 959
# 最优值： 0.1806224 扰动程度： 8.930211760278565 代数： 960
# 最优值： 0.17753908 扰动程度： 8.992513270262956 代数： 961
# 最优值： 0.1728846 扰动程度： 9.078596123117865 代数： 962
# 最优值： 0.17303951 扰动程度： 9.07924229876623 代数： 963
# 最优值： 0.1689572 扰动程度： 9.137284292628426 代数： 964
# 最优值： 0.16557598 扰动程度： 9.225188092066649 代数： 965
# 最优值： 0.16046056 扰动程度： 9.317744276922241 代数： 966
# 最优值： 0.15948051 扰动程度： 9.327003933603674 代数： 967
# 最优值： 0.1563666 扰动程度： 9.321805309984844 代数： 968
# 最优值： 0.15642038 扰动程度： 9.418188181434765 代数： 969
# 最优值： 0.1549298 扰动程度： 9.457959711530567 代数： 970
# 最优值： 0.1499461 扰动程度： 9.48656441631793 代数： 971
# 最优值： 0.14801957 扰动程度： 9.50077211020682 代数： 972
# 最优值： 0.1478158 扰动程度： 9.532470834054452 代数： 973
# 最优值： 0.14380442 扰动程度： 9.638618698402269 代数： 974
# 最优值： 0.14111625 扰动程度： 9.723705495062616 代数： 975
# 最优值： 0.1403337 扰动程度： 9.736581245363897 代数： 976
# 最优值： 0.14011034 扰动程度： 9.746875801556742 代数： 977
# 最优值： 0.13731171 扰动程度： 9.845677734896315 代数： 978
# 最优值： 0.13420118 扰动程度： 9.885346620080467 代数： 979
# 最优值： 0.13193062 扰动程度： 9.981477274221362 代数： 980

# %%
BEST_X
# Out:
# array([ 0.00000000e+00,  1.12291523e-02,  4.22988203e-02,  2.12128627e-06,
#         8.56197183e-03,  1.33234895e-04,  0.00000000e+00,  1.67651070e-03,
#         1.13954045e-03,  8.88149397e-02,  0.00000000e+00,  0.00000000e+00,
#         2.05403298e-01,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.11169477e-02,  6.92583745e-05,  5.46083869e-02,
#         1.93278949e-01, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         8.35477324e-09,  0.00000000e+00,  3.72101798e-04,  1.86307333e-01,
#         3.62133804e-03,  2.64553382e-04,  0.00000000e+00,  1.34234452e-06,
#         0.00000000e+00,  0.00000000e+00,  7.61389463e-07,  0.00000000e+00,
#         0.00000000e+00,  6.35557081e-02,  2.56904145e-05,  0.00000000e+00,
#         3.88962725e-03, -0.00000000e+00,  1.26941265e-03,  5.61394451e-02,
#         1.45497418e-02,  4.52919618e-03,  1.14664332e-03,  1.35964303e-04,
#         2.62873627e-04,  1.64612472e-01,  0.00000000e+00,  9.34312856e-03,
#         0.00000000e+00,  0.00000000e+00,  9.20344073e-03,  1.58217537e-05,
#         7.76982535e-05,  0.00000000e+00,  1.48686123e-02,  0.00000000e+00,
#         1.71066327e-01,  5.03326202e-01,  3.07748825e-02,  0.00000000e+00,
#         2.61532722e-09,  2.72650519e-01,  0.00000000e+00,  1.63325699e-04,
#         2.67724119e-02,  0.00000000e+00,  4.16051891e-03,  9.50305495e-03,
#         3.01062765e-04,  7.81178569e-04,  0.00000000e+00,  0.00000000e+00,
#         6.41655189e-05,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  8.66470789e-03,  3.90664917e-05,
#         0.00000000e+00,  7.15968390e-02,  0.00000000e+00,  3.66268920e-06,
#         3.89096954e-02,  1.22714170e-01,  1.07348690e-02,  3.43267258e-03,
#         3.47007597e-03,  1.46396756e-05,  3.57053661e-03,  0.00000000e+00,
#         0.00000000e+00,  1.16618065e-03,  0.00000000e+00,  0.00000000e+00,
#         2.71953727e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.91609584e-04,  0.00000000e+00,  0.00000000e+00,
#         5.83120609e-04,  0.00000000e+00,  0.00000000e+00,  6.88886151e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.12991345e-05,
#         0.00000000e+00,  0.00000000e+00,  2.86608090e-04,  0.00000000e+00,
#         8.79389805e-02,  2.81071548e-04,  3.39098359e-03,  3.21299328e-01,
#         1.97122521e-01,  3.70175154e-01,  0.00000000e+00,  2.26334928e-01,
#         1.87002369e-01,  0.00000000e+00,  2.32330631e-02,  6.23058007e-03,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  3
.00000000e+00,
        0.00000000e+00,  0.00000000e+00,  3.12616212e-02,  8.74425915e-03,
        3.16844550e-05,  0.00000000e+00,  0.00000000e+00,  5.20809070e-04,
        0.00000000e+00,  0.00000000e+00, -9.38451006e-03, -1.29273835e-02,
       -1.65884713e-01,  9.95947254e-05,  1.28134225e-02,  0.00000000e+00,
        0.00000000e+00,  0.00000000e+00,  5.61713280e-04, -0.00000000e+00,
        0.00000000e+00,  5.40406741e-02,  0.00000000e+00,  0.00000000e+00,
        5.46063028e-03,  1.53739314e-02,  0.00000000e+00,  3.35924544e-03,
        0.00000000e+00,  6.05677739e-05,  2.16842708e-03,  3.41250353e-03,
        0.00000000e+00,  0.00000000e+00,  2.97435142e-02,  1.68249069e-03,
        0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -2.38449227e-02,
       -5.21959898e-05, -2.31468904e-02,  0.00000000e+00,  0.00000000e+00,
        5.40254759e-04, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
        1.21554002e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
        0.00000000e+00,  1.37694629e-01,  0.00000000e+00,  0.00000000e+00,
        1.82122309e-02,  9.23621013e-05,  5.90423432e-03,  1.09421432e-03,
        1.29115106e-01,  1.16387775e-01,  3.49655997e-04,  0.00000000e+00,
        0.00000000e+00,  0.00000000e+00,  1.18940318e-04,  1.79455656e-01,
        7.45207254e-02,  3.09738418e-04,  1.60013815e-02,  0.00000000e+00,
        6.69385775e-05,  0.00000000e+00,  0.00000000e+00,  4.31482036e-04,
        0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
        1.82737511e-02,  6.24068276e-02,  6.52179969e-03,  0.00000000e+00])

# %%
BEST = BEST_X + x_test[0]
plt.imshow(BEST.reshape(28,28),cmap='gray')
plt.show()

# %%
result=model.predict(BEST_X.reshape(1,784))
result[0]
# Out:
# array([0.03606191, 0.13325453, 0.30351505, 0.14268604, 0.03217717,
#        0.18159828, 0.06348677, 0.01640903, 0.07245255, 0.01835869],
#       dtype=float32)

# %%
# test
count = 0
for i in range(784):
    if BEST_X[i] != 0:
        count+=1
print(count)
# Out:
# 498

# %%
# test
count = 0
for i in range(784):
    if BEST_X[i] > 0.8:
        count+=1
print(count)
# Out:
# 0

# %%
#过滤（低强度）
import copy
x_f = copy.deepcopy(BEST_X)
for i in range(784):
    if abs(x_f[i]) < 0.2:
        x_f[i] = 0
f = x_f+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
result=model.predict(f.reshape(1,784))
print("置信度：", result[0][7])
print(result[0])
print("扰动程度：",Dis(x_f))
# Out:
# 置信度： 0.79100835
# [1.5174575e-03 6.5535348e-04 4.4565573e-02 1.5166000e-01 1.2409961e-04
#  4.1875131e-03 1.3115628e-05 7.9100835e-01 2.5698482e-03 3.6986568e-03]
# 扰动程度： 5.808045297534583

# %%
#过滤（高强度）
import copy
x_F = copy.deepcopy(BEST_X)
for i in range(784):
    if abs(x_F[i]) > 0.5:
        x_F[i] = 0
F = x_F+x_test[0]
plt.imshow(F.reshape(28,28),cmap='gray')
plt.show()
result=model.predict(F.reshape(1,784))
print("置信度：", result[0][7])
print(result[0])
print("扰动程度：",Dis(x_F))
# Out:
# 置信度： 0.7140484
# [3.5013091e-03 7.0029777e-04 8.5273638e-02 1.8356721e-01 1.1966820e-04
#  6.3261571e-03 2.0771509e-05 7.1404839e-01 3.2437495e-03 3.1988441e-03]
# 扰动程度： 5.399337470712778

# %%
# 改变坐标减小置信度（过滤0.2）
import copy
x_t = copy.deepcopy(x_f)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代: 1
# 置信度： 0.79081285
# 迭代: 2
# 置信度： 0.78750575
# 迭代: 3
# 置信度： 0.7869196
# 迭代: 4
# 置信度： 0.7822701
# 迭代: 5
# 置信度： 0.78187114
# 迭代: 6
# 置信度： 0.777245
# 迭代: 7
# 置信度： 0.7769792
# 迭代: 8
# 置信度： 0.77427053
# 迭代: 9
# 置信度： 0.7742648
# 迭代: 10
# 置信度： 0.77287626
# 迭代: 11
# 置信度： 0.7688211
# 迭代: 12
# 置信度： 0.76710916
# 迭代: 13
# 置信度： 0.76175636
# 迭代: 14
# 置信度： 0.754947
# 迭代: 15
# 置信度： 0.73712313
# 迭代: 16
# 置信度： 0.73679423
# 迭代: 17
# 置信度： 0.7302526
# 迭代: 18
# 置信度： 0.7288987
# 迭代: 19
# 置信度： 0.72669345
# 迭代: 20
# 置信度： 0.7041881
# 迭代: 21
# 置信度： 0.69990194
# 迭代: 22
# 置信度： 0.69171655
# 迭代: 23
# 置信度： 0.69031096
# 迭代: 24
# 置信度： 0.6852583
# 迭代: 25
# 置信度： 0.6840442
# 迭代: 26
# 置信度： 0.672793
# 迭代: 27
# 置信度： 0.6632727
# 迭代: 28
# 置信度： 0.6593912
# 迭代: 29
# 置信度： 0.65689915
# 迭代: 30
# 置信度： 0.642851
# 迭代: 31
# 置信度： 0.6423891
# 迭代: 32
# 置信度： 0.6416772
# 迭代: 33
# 置信度： 0.6382753
# 迭代: 34
# 置信度： 0.6347022
# 迭代: 35
# 置信度： 0.6346574
# 迭代: 36
# 置信度： 0.6339686
# 迭代: 37
# 置信度： 0.63303316
# 迭代: 38
# 置信度： 0.6291769
# 迭代: 39
# 置信度： 0.6288673
# 迭代: 40
# 置信度： 0.6225137
# 迭代: 41
# 置信度： 0.6176364
# 迭代: 42
# 置信度： 0.61705863
# 迭代: 43
# 置信度： 0.611814
# 迭代: 44
# 置信度： 0.6064441
# 迭代: 45
# 置信度： 0.5942284
# 迭代失败
# 最终置信度： 0.5942284
# 最终扰动程度： 5.808045297534582
# [1.0967220e-03 9.6672133e-04 4.5148227e-02 3.4004280e-01 1.6902824e-04
#  4.2748246e-03 1.2764148e-05 5.9422839e-01 6.3656499e-03 7.6948670e-03]

# %%
# 改变坐标减小置信度（过滤0.5）
import copy
x_t = copy.deepcopy(x_F)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代失败
# 最终置信度： 0.7140484
# 最终扰动程度： 5.399337470712778
# [3.5013091e-03 7.0029777e-04 8.5273638e-02 1.8356721e-01 1.1966820e-04
#  6.3261571e-03 2.0771509e-05 7.1404839e-01 3.2437495e-03 3.1988441e-03]

# %%
# 改变坐标减小置信度
import copy
x_t = copy.deepcopy(BEST_X)
count = 0
for t in range(80):
    x_f1 = copy.deepcopy(x_t)
    con = 0
    while con < 1000:
        for i in range(784):
            if x_f1[i] > 0:
                x= random.randint(0,10000)/10000
                if x <= 0.1:
                    x_z = x_f1[i]
                    y = random.randint(0,783)
                    f_y = x_f1[y]+x_test[0][i]
                    f_i = x_f1[i]+x_test[0][y]
                    if  (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                        while (f_y >= 1.00000000e+00 or f_y < 0.00000000e+00) or (f_i >= 1.00000000e+00 or f_i < 0.00000000e+00):
                            y = random.randint(0,783)
                            f_y = x_f1[y]+x_test[0][i]
                            f_i = x_f1[i]+x_test[0][y]
                    x_f1[i] = x_f1[y]
                    x_f1[y] = x_z
        #print(Func(x_f1))
        con += 1
        if Func(x_f1) < Func(x_t):
            x_t = x_f1
            count += 1
            print("迭代:",count)
            print("置信度：",Func(x_t))
            f1 = x_t+x_test[0]
            plt.imshow(f1.reshape(28,28),cmap='gray')
            plt.show()
            break
        x_f1 = copy.deepcopy(x_t)
    if con == 1000:
        print("迭代失败")
        break
f = x_t+x_test[0]
plt.imshow(f.reshape(28,28),cmap='gray')
plt.show()
res=model.predict(f.reshape(1,784))
print("最终置信度：", res[0][7])
print("最终扰动程度：", Dis(x_t))
print(res[0])
# Out:
# 迭代失败
# 最终置信度： 0.39767227
# 最终扰动程度： 7.0038201815486
# [3.7777259e-03 1.0443135e-03 1.1682559e-01 4.5660120e-01 1.5665211e-04
#  1.2439688e-02 3.2627453e-05 3.9767227e-01 7.4698036e-03 3.9801179e-03]
